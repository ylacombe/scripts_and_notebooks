# %% [markdown]
# <a href="https://colab.research.google.com/github/ylacombe/scripts_and_notebooks/blob/main/Finetuning_Parler_TTS_on_a_single_speaker_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fine-tuning Parler-TTS
#
# ## Goal of this notebook
#
# In the following notebook, we'll fine-tune [Parler-TTS Mini v0.1](https://huggingface.co/parler-tts/parler_tts_mini_v0.1) on a 5h subset of the [Jenny TTS dataset](https://github.com/dioco-group/jenny-tts-dataset), a 30 hours high-quality mono-speaker TTS dataset, from an Irish female speaker named Jenny.
#
# In particular, we'll:
# - Annotate the Jenny dataset with natural language speech description using [Data-Speech](https://github.com/huggingface/dataspeech).
# - Fine-tune Parler-TTS with the created dataset.
#
# **You should be able to adapt this notebook to your own datasets quite easily.**

# %% [markdown]
# ## Prepare the Environment
#
# Throughout this tutorial, we'll use a GPU. The runtime is already configured to use the free 16GB T4 GPU provided through Google Colab Free Tier, so all you need to do is hit "Connect T4" in the top right-hand corner of the screen.
#
# ##### <a name="installation"> We'll install Parler-TTS and Data-Speech from source in order to train our model.

# %%
# !git clone https://github.com/huggingface/dataspeech.git
# !cd dataspeech
# !pip install --quiet -r ./dataspeech/requirements.txt
# Out:
# Cloning into 'dataspeech'...
# remote: Enumerating objects: 383, done.
# remote: Counting objects: 100% (101/101), done.
# remote: Compressing objects: 100% (67/67), done.
# remote: Total 383 (delta 57), reused 55 (delta 34), pack-reused 282
# Receiving objects: 100% (383/383), 102.50 KiB | 846.00 KiB/s, done.
# Resolving deltas: 100% (219/219), done.
#      | 49.0 MB 43.0 MB/s 0:00:04
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 8.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 18.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 26.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.6/297.6 kB 25.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 8.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 13.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 13.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.9/388.9 kB 24.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.7/208.7 kB 19.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.9/43.9 kB 4.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 26.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 360.5/360.5 kB 31.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.7/75.7 kB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.1/87.1 kB 11.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 8.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.8/239.8 kB 28.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.0/40.0 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 11.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 7.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 82.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 11.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 9.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.1/48.1 kB 7.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.4/51.4 kB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.1/119.1 kB 17.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 760.1/760.1 kB 65.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 14.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 841.5/841.5 kB 69.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.7/74.7 kB 10.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 75.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.2/802.2 kB 69.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 16.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 6.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.1/380.1 kB 41.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 30.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.8/117.8 kB 11.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 12.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.7/526.7 kB 52.8 MB/s eta 0:00:00
#   Building wheel for brouhaha (setup.py) ... done
#   Building wheel for demucs (setup.py) ... done
#   Building wheel for julius (setup.py) ... done
#   Building wheel for dora-search (pyproject.toml) ... done
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Building wheel for treetable (setup.py) ... done
#   Building wheel for unicodecsv (setup.py) ... done
#   Building wheel for docopt (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spacy 3.7.4 requires typer<0.10.0,>=0.3.0, but you have typer 0.12.3 which is incompatible.
# weasel 0.3.4 requires typer<0.10.0,>=0.3.0, but you have typer 0.12.3 which is incompatible.

# %%
# !git clone https://github.com/huggingface/parler-tts.git
# %cd parler-tts
# !pip install --quiet -e .[train]
# Out:
# Cloning into 'parler-tts'...
# remote: Enumerating objects: 683, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 683 (delta 16), reused 15 (delta 15), pack-reused 662
# Receiving objects: 100% (683/683), 252.49 KiB | 1.02 MiB/s, done.
# Resolving deltas: 100% (418/418), done.
# /content/parler-tts
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 13.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 12.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.7/106.7 kB 16.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 16.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 24.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.8/266.8 kB 32.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 9.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 35.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 44.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 11.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building editable for parler_tts (pyproject.toml) ... done
#   Building wheel for argbind (setup.py) ... done
#   Building wheel for ffmpy (setup.py) ... done
#   Building wheel for randomname (setup.py) ... done
#   Building wheel for fire (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorboardx 2.6.2.2 requires protobuf>=3.20, but you have protobuf 3.19.6 which is incompatible.
# tensorflow 2.15.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 3.19.6 which is incompatible.
# tensorflow-datasets 4.9.4 requires protobuf>=3.20, but you have protobuf 3.19.6 which is incompatible.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 3.19.6 which is incompatible.

# %% [markdown]
# On Colab, we need to run an additional set-up, that you can skip if you're on your local machine.

# %%
# !pip install --upgrade protobuf wandb==0.16.6
# Out:
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (4.25.3)
# Collecting protobuf
#   Using cached protobuf-5.26.1-cp37-abi3-manylinux2014_x86_64.whl (302 kB)
# Requirement already satisfied: wandb==0.16.6 in /usr/local/lib/python3.10/dist-packages (0.16.6)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb==0.16.6) (8.1.7)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb==0.16.6) (3.1.43)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb==0.16.6) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb==0.16.6) (5.9.5)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb==0.16.6) (2.0.1)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from wandb==0.16.6) (0.4.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from wandb==0.16.6) (6.0.1)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.10/dist-packages (from wandb==0.16.6) (1.3.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb==0.16.6) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb==0.16.6) (1.4.4)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb==0.16.6) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from GitPython!=3.1.29,>=1.0.0->wandb==0.16.6) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb==0.16.6) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb==0.16.6) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb==0.16.6) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb==0.16.6) (2024.2.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb==0.16.6) (5.0.1)

# %% [markdown]
# You should link you Hugging Face account so that you can push model repositories on the Hub. This will allow you to save your trained models on the Hub so that you can share them with the community.
#
# Run the command below and then enter an authentication token from https://huggingface.co/settings/tokens. Create a new token if you do not have one already. You should make sure that this token has "write" privileges.

# %%
# !git config --global credential.helper store
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) Y
# Token is valid (permission: write).
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# ## 1. Creating our fine-tuning dataset
#
#
# The aim here is to create an annotated version of Jenny TTS, in order to fine-tune the [Parler-TTS v0.1 checkpoint](https://huggingface.co/parler-tts/parler_tts_mini_v0.1) on this dataset.
#
# Thanks to a [script similar to what's described in the Data-Speech FAQ](https://github.com/huggingface/dataspeech?tab=readme-ov-file#how-do-i-use-datasets-that-i-have-with-this-repository), we've uploaded the dataset to the HuggingFace hub, under the name [reach-vb/jenny_tts_dataset](https://huggingface.co/datasets/reach-vb/jenny_tts_dataset).
#
# The purpose of this notebook is demonstration so we've pushed a 6h subset of the dataset that we'll work with: [ylacombe/jenny-tts-6h](https://huggingface.co/datasets/ylacombe/jenny-tts-6h).
#
# Feel free to follow the link above to listen to some samples of the Jenny TTS dataset thanks to the hub viewer.
#
# > Refer to the [Data-Speech README](https://github.com/huggingface/dataspeech?tab=readme-ov-file#data-speech) for more detailed explanations of what's going on under-the-hood.
#
# We'll:
# 1. Annotate the Jenny dataset with continuous variables that measures the speech characteristics
# 2. Map those annotations to text bins that characterize the speech characteristics.
# 3. Create natural language descriptions from those text bins

# %%
# %cd ../dataspeech
# Out:
# /content/dataspeech

# %% [markdown]
# But first, let's look at a few samples from the Jenny dataset!

# %%
from datasets import load_dataset
dataset = load_dataset("ylacombe/jenny-tts-6h")

# %%
from IPython.display import Audio
print(dataset["train"][0]["transcription"])
Audio(dataset["train"][0]["audio"]["array"], rate=dataset["train"][0]["audio"]["sampling_rate"])
# Out:
# It was a bright cold day in April, and the clocks were striking thirteen.
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from IPython.display import Audio
print(dataset["train"][1]["transcription"])
Audio(dataset["train"][1]["audio"]["array"], rate=dataset["train"][1]["audio"]["sampling_rate"])
# Out:
# 'I wonder if I shall ever be happy enough to have real lace on my clothes and bows on my caps?'
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
del dataset

# %% [markdown]
# ### Annotating the Jenny dataset
#
# We'll use [`main.py`](https://github.com/huggingface/dataspeech/blob/main/main.py) to get the following continuous variables:
# - Speaking rate `(nb_phonemes / utterance_length)`
# - Signal-to-noise ratio (SNR)
# - Reverberation
# - Speech monotony

# %%
# !python main.py "ylacombe/jenny-tts-6h" \
  --configuration "default" \
  --text_column_name "transcription" \
  --audio_column_name "audio" \
  --cpu_num_workers 2 \
  --num_workers_per_gpu_for_pitch 2 \
  --rename_column \
  --repo_id "jenny-tts-tags-6h"
# Out:
# 2024-04-30 13:39:55.287417: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-30 13:39:55.287475: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-30 13:39:55.288924: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-30 13:39:55.296346: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-30 13:39:56.415995: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/pyannote/audio/core/io.py:43: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("soundfile")
# Compute pitch
# Map (num_proc=2):   0% 0/4000 [00:00<?, ? examples/s]2024-04-30 13:40:18.233303: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-30 13:40:18.233361: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-30 13:40:18.237005: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-30 13:40:18.465774: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-30 13:40:18.465827: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-30 13:40:18.467567: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-30 13:40:19.049881: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-30 13:40:19.049961: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-30 13:40:19.051550: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-30 13:40:21.017798: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-04-30 13:40:21.141991: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-04-30 13:40:21.773434: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/pyannote/audio/core/io.py:43: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("soundfile")
# /usr/local/lib/python3.10/dist-packages/pyannote/audio/core/io.py:43: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("soundfile")
# /usr/local/lib/python3.10/dist-packages/pyannote/audio/core/io.py:43: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("soundfile")
# fcnf0++.pt: 100% 107M/107M [00:00<00:00, 238MB/s]
# Map (num_proc=2): 100% 4000/4000 [04:25<00:00, 15.05 examples/s]
# Compute snr and reverb
# Map:   0% 0/4000 [00:00<?, ? examples/s]
# best.ckpt:   0% 0.00/47.2M [00:00<?, ?B/s]
# best.ckpt: 100% 47.2M/47.2M [00:00<00:00, 212MB/s]
# INFO - Lightning automatically upgraded your loaded checkpoint from v1.6.5 to v2.2.3. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint ../../root/.cache/huggingface/hub/models--ylacombe--brouhaha-best/snapshots/99bf97b13fd4dda2434a6f7c50855933076f2937/best.ckpt`
# Model was trained with pyannote.audio 0.0.1, yours is 3.1.1. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.12.1+cu102, yours is 2.2.1+cu121. Bad things might happen unless you revert torch to 1.x.
# Using default parameters optimized on Brouhaha
# Map:   0% 2/4000 [00:02<1:32:23,  1.39s/ examples]Using default parameters optimized on Brouhaha
# Map:   0% 4/4000 [00:02<40:41,  1.64 examples/s]  Using default parameters optimized on Brouhaha
# Map:   0% 6/4000 [00:03<24:35,  2.71 examples/s]Using default parameters optimized on Brouhaha
# Map:   0% 8/4000 [00:03<17:10,  3.87 examples/s]Using default parameters optimized on Brouhaha
# Map:   0% 10/4000 [00:03<12:42,  5.23 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   0% 14/4000 [00:03<08:19,  7.98 examples/s]Using default parameters optimized on Brouhaha
# Map:   0% 16/4000 [00:03<07:25,  8.95 examples/s]Using default parameters optimized on Brouhaha
# Map:   0% 18/4000 [00:03<06:38, 10.00 examples/s]Using default parameters optimized on Brouhaha
# Map:   0% 20/4000 [00:04<06:01, 11.02 examples/s]Using default parameters optimized on Brouhaha
# Map:   1% 22/4000 [00:04<05:34, 11.88 examples/s]Using default parameters optimized on Brouhaha
# Map:   1% 24/4000 [00:04<05:09, 12.85 examples/s]Using default parameters optimized on Brouhaha
# Map:   1% 26/4000 [00:04<04:36, 14.35 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1% 30/4000 [00:04<03:38, 18.19 examples/s]Using default parameters optimized on Brouhaha
# Map:   1% 32/4000 [00:04<03:46, 17.49 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1% 36/4000 [00:04<03:07, 21.18 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1% 40/4000 [00:05<03:08, 21.03 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1% 44/4000 [00:05<02:53, 22.82 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1% 48/4000 [00:05<02:47, 23.53 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1% 52/4000 [00:05<02:38, 24.93 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   1% 56/4000 [00:05<03:07, 21.09 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2% 60/4000 [00:06<03:37, 18.11 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2% 64/4000 [00:06<03:38, 17.97 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2% 68/4000 [00:06<03:26, 19.08 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2% 72/4000 [00:06<02:54, 22.47 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2% 76/4000 [00:06<02:38, 24.73 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2% 80/4000 [00:06<02:40, 24.43 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2% 84/4000 [00:06<02:37, 24.90 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2% 88/4000 [00:07<02:45, 23.70 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2% 92/4000 [00:07<02:34, 25.36 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2% 96/4000 [00:07<02:33, 25.47 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   2% 100/4000 [00:07<02:38, 24.57 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3% 104/4000 [00:07<02:43, 23.76 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3% 108/4000 [00:08<02:58, 21.81 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3% 112/4000 [00:08<03:06, 20.84 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3% 116/4000 [00:08<03:42, 17.45 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3% 120/4000 [00:08<03:47, 17.07 examples/s]Using default parameters optimized on Brouhaha
# Map:   3% 122/4000 [00:08<03:53, 16.60 examples/s]Using default parameters optimized on Brouhaha
# Map:   3% 124/4000 [00:09<04:00, 16.10 examples/s]Using default parameters optimized on Brouhaha
# Map:   3% 126/4000 [00:09<04:25, 14.59 examples/s]Using default parameters optimized on Brouhaha
# Map:   3% 128/4000 [00:09<04:19, 14.92 examples/s]Using default parameters optimized on Brouhaha
# Map:   3% 130/4000 [00:09<04:55, 13.11 examples/s]Using default parameters optimized on Brouhaha
# Map:   3% 132/4000 [00:09<05:31, 11.66 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   3% 136/4000 [00:10<04:38, 13.90 examples/s]Using default parameters optimized on Brouhaha
# Map:   3% 138/4000 [00:10<04:38, 13.85 examples/s]Using default parameters optimized on Brouhaha
# Map:   4% 140/4000 [00:10<04:28, 14.37 examples/s]Using default parameters optimized on Brouhaha
# Map:   4% 142/4000 [00:10<04:36, 13.93 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4% 146/4000 [00:10<03:57, 16.26 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4% 150/4000 [00:10<03:27, 18.57 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4% 154/4000 [00:11<03:26, 18.61 examples/s]Using default parameters optimized on Brouhaha
# Map:   4% 156/4000 [00:11<03:37, 17.69 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4% 160/4000 [00:11<03:13, 19.88 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4% 164/4000 [00:11<02:53, 22.12 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4% 168/4000 [00:11<02:45, 23.12 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4% 172/4000 [00:11<02:49, 22.55 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4% 176/4000 [00:11<02:32, 25.10 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   4% 180/4000 [00:12<02:18, 27.63 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   5% 184/4000 [00:12<02:12, 28.79 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   5% 188/4000 [00:12<02:06, 30.04 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   5% 192/4000 [00:12<02:17, 27.62 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   5% 196/4000 [00:12<02:26, 26.03 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   5% 200/4000 [00:12<02:32, 24.84 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   5% 204/4000 [00:12<02:39, 23.86 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   5% 208/4000 [00:13<02:54, 21.71 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   5% 212/4000 [00:13<03:10, 19.86 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   5% 216/4000 [00:13<02:57, 21.31 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   6% 220/4000 [00:13<02:43, 23.08 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   6% 224/4000 [00:13<02:41, 23.39 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   6% 228/4000 [00:14<02:48, 22.33 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   6% 232/4000 [00:14<02:59, 21.00 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   6% 236/4000 [00:14<02:40, 23.47 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   6% 240/4000 [00:14<02:44, 22.82 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   6% 244/4000 [00:14<02:27, 25.53 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   6% 248/4000 [00:14<02:38, 23.72 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   6% 252/4000 [00:15<02:46, 22.51 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   6% 256/4000 [00:15<03:03, 20.44 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   6% 260/4000 [00:15<03:01, 20.66 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   7% 264/4000 [00:15<03:18, 18.84 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   7% 268/4000 [00:15<03:03, 20.29 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   7% 272/4000 [00:16<03:31, 17.67 examples/s]Using default parameters optimized on Brouhaha
# Map:   7% 274/4000 [00:16<03:33, 17.47 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   7% 278/4000 [00:16<03:20, 18.58 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   7% 282/4000 [00:16<03:09, 19.63 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   7% 286/4000 [00:16<03:09, 19.56 examples/s]Using default parameters optimized on Brouhaha
# Map:   7% 288/4000 [00:17<03:14, 19.10 examples/s]Using default parameters optimized on Brouhaha
# Map:   7% 290/4000 [00:17<03:15, 18.97 examples/s]Using default parameters optimized on Brouhaha
# Map:   7% 292/4000 [00:17<03:22, 18.34 examples/s]Using default parameters optimized on Brouhaha
# Map:   7% 294/4000 [00:17<03:49, 16.17 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   7% 298/4000 [00:17<03:34, 17.25 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   8% 302/4000 [00:17<03:15, 18.93 examples/s]Using default parameters optimized on Brouhaha
# Map:   8% 304/4000 [00:18<03:25, 17.95 examples/s]Using default parameters optimized on Brouhaha
# Map:   8% 306/4000 [00:18<03:33, 17.29 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   8% 310/4000 [00:18<03:18, 18.57 examples/s]Using default parameters optimized on Brouhaha
# Map:   8% 312/4000 [00:18<03:26, 17.84 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   8% 316/4000 [00:18<03:24, 18.01 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   8% 320/4000 [00:18<03:02, 20.14 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   8% 324/4000 [00:18<02:45, 22.20 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   8% 328/4000 [00:19<03:16, 18.71 examples/s]Using default parameters optimized on Brouhaha
# Map:   8% 330/4000 [00:19<03:28, 17.58 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   8% 334/4000 [00:19<03:15, 18.80 examples/s]Using default parameters optimized on Brouhaha
# Map:   8% 336/4000 [00:19<03:13, 18.96 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   8% 340/4000 [00:19<02:51, 21.35 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   9% 344/4000 [00:19<02:40, 22.82 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   9% 348/4000 [00:20<02:42, 22.52 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   9% 352/4000 [00:20<02:36, 23.33 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   9% 356/4000 [00:20<02:59, 20.31 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   9% 360/4000 [00:20<03:32, 17.09 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   9% 364/4000 [00:21<03:31, 17.16 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:   9% 368/4000 [00:21<03:48, 15.87 examples/s]Using default parameters optimized on Brouhaha
# Map:   9% 370/4000 [00:21<04:08, 14.62 examples/s]Using default parameters optimized on Brouhaha
# Map:   9% 372/4000 [00:21<04:18, 14.05 examples/s]Using default parameters optimized on Brouhaha
# Map:   9% 374/4000 [00:21<04:10, 14.49 examples/s]Using default parameters optimized on Brouhaha
# Map:   9% 376/4000 [00:22<04:31, 13.34 examples/s]Using default parameters optimized on Brouhaha
# Map:   9% 378/4000 [00:22<04:08, 14.57 examples/s]Using default parameters optimized on Brouhaha
# Map:  10% 380/4000 [00:22<04:20, 13.91 examples/s]Using default parameters optimized on Brouhaha
# Map:  10% 382/4000 [00:22<04:03, 14.85 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  10% 386/4000 [00:22<03:29, 17.24 examples/s]Using default parameters optimized on Brouhaha
# Map:  10% 388/4000 [00:22<03:45, 16.02 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  10% 392/4000 [00:22<03:11, 18.87 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  10% 396/4000 [00:23<03:05, 19.39 examples/s]Using default parameters optimized on Brouhaha
# Map:  10% 398/4000 [00:23<03:05, 19.37 examples/s]Using default parameters optimized on Brouhaha
# Map:  10% 400/4000 [00:23<03:15, 18.43 examples/s]Using default parameters optimized on Brouhaha
# Map:  10% 402/4000 [00:23<03:12, 18.71 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  10% 406/4000 [00:23<02:46, 21.55 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  10% 410/4000 [00:23<02:34, 23.28 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  10% 414/4000 [00:24<02:51, 20.90 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  10% 418/4000 [00:24<02:43, 21.84 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  11% 422/4000 [00:24<02:41, 22.12 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  11% 426/4000 [00:24<02:32, 23.37 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  11% 430/4000 [00:24<03:13, 18.48 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  11% 434/4000 [00:25<03:20, 17.82 examples/s]Using default parameters optimized on Brouhaha
# Map:  11% 436/4000 [00:25<03:26, 17.28 examples/s]Using default parameters optimized on Brouhaha
# Map:  11% 438/4000 [00:25<03:34, 16.61 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  11% 442/4000 [00:25<03:03, 19.39 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  11% 446/4000 [00:25<03:06, 19.10 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  11% 450/4000 [00:25<02:49, 20.96 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  11% 454/4000 [00:25<02:29, 23.65 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  11% 458/4000 [00:26<02:25, 24.37 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  12% 462/4000 [00:26<02:21, 24.92 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  12% 466/4000 [00:26<02:55, 20.18 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  12% 470/4000 [00:26<02:32, 23.18 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  12% 474/4000 [00:26<03:08, 18.74 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  12% 478/4000 [00:27<02:45, 21.26 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  12% 482/4000 [00:27<02:41, 21.80 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  12% 486/4000 [00:27<02:52, 20.31 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  12% 490/4000 [00:27<02:58, 19.71 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  12% 494/4000 [00:28<03:21, 17.37 examples/s]Using default parameters optimized on Brouhaha
# Map:  12% 496/4000 [00:28<03:28, 16.83 examples/s]Using default parameters optimized on Brouhaha
# Map:  12% 498/4000 [00:28<03:45, 15.53 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  13% 502/4000 [00:28<03:27, 16.83 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  13% 506/4000 [00:28<03:13, 18.02 examples/s]Using default parameters optimized on Brouhaha
# Map:  13% 508/4000 [00:28<03:11, 18.26 examples/s]Using default parameters optimized on Brouhaha
# Map:  13% 510/4000 [00:28<03:08, 18.56 examples/s]Using default parameters optimized on Brouhaha
# Map:  13% 512/4000 [00:29<03:23, 17.11 examples/s]Using default parameters optimized on Brouhaha
# Map:  13% 514/4000 [00:29<03:18, 17.52 examples/s]Using default parameters optimized on Brouhaha
# Map:  13% 516/4000 [00:29<03:21, 17.30 examples/s]Using default parameters optimized on Brouhaha
# Map:  13% 518/4000 [00:29<03:53, 14.91 examples/s]Using default parameters optimized on Brouhaha
# Map:  13% 520/4000 [00:29<04:05, 14.17 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  13% 524/4000 [00:29<03:18, 17.50 examples/s]Using default parameters optimized on Brouhaha
# Map:  13% 526/4000 [00:29<03:24, 16.95 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  13% 530/4000 [00:30<02:54, 19.94 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  13% 534/4000 [00:30<02:31, 22.94 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  13% 538/4000 [00:30<02:35, 22.29 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  14% 542/4000 [00:30<02:35, 22.17 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  14% 546/4000 [00:30<02:35, 22.17 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  14% 550/4000 [00:30<02:37, 21.96 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  14% 554/4000 [00:31<02:19, 24.68 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  14% 558/4000 [00:31<02:38, 21.68 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  14% 562/4000 [00:31<02:24, 23.79 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  14% 566/4000 [00:31<02:31, 22.60 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  14% 570/4000 [00:31<02:57, 19.36 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  14% 574/4000 [00:32<03:06, 18.39 examples/s]Using default parameters optimized on Brouhaha
# Map:  14% 576/4000 [00:32<03:13, 17.71 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  14% 580/4000 [00:32<03:13, 17.67 examples/s]Using default parameters optimized on Brouhaha
# Map:  15% 582/4000 [00:32<03:13, 17.69 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  15% 586/4000 [00:32<02:56, 19.30 examples/s]Using default parameters optimized on Brouhaha
# Map:  15% 588/4000 [00:32<03:11, 17.83 examples/s]Using default parameters optimized on Brouhaha
# Map:  15% 590/4000 [00:33<03:25, 16.58 examples/s]Using default parameters optimized on Brouhaha
# Map:  15% 592/4000 [00:33<04:05, 13.87 examples/s]Using default parameters optimized on Brouhaha
# Map:  15% 594/4000 [00:33<04:38, 12.22 examples/s]Using default parameters optimized on Brouhaha
# Map:  15% 596/4000 [00:33<04:30, 12.58 examples/s]Using default parameters optimized on Brouhaha
# Map:  15% 598/4000 [00:33<04:34, 12.37 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  15% 602/4000 [00:34<03:59, 14.20 examples/s]Using default parameters optimized on Brouhaha
# Map:  15% 604/4000 [00:34<04:00, 14.09 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  15% 608/4000 [00:34<03:43, 15.20 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  15% 612/4000 [00:34<03:22, 16.75 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  15% 616/4000 [00:34<03:23, 16.61 examples/s]Using default parameters optimized on Brouhaha
# Map:  15% 618/4000 [00:34<03:17, 17.15 examples/s]Using default parameters optimized on Brouhaha
# Map:  16% 620/4000 [00:35<03:26, 16.39 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  16% 624/4000 [00:35<02:58, 18.95 examples/s]Using default parameters optimized on Brouhaha
# Map:  16% 626/4000 [00:35<02:57, 18.98 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  16% 630/4000 [00:35<02:38, 21.21 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  16% 634/4000 [00:35<02:45, 20.32 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  16% 638/4000 [00:35<02:58, 18.81 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  16% 642/4000 [00:36<02:50, 19.70 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  16% 646/4000 [00:36<02:36, 21.42 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  16% 650/4000 [00:36<02:27, 22.71 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  16% 654/4000 [00:36<02:26, 22.86 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  16% 658/4000 [00:36<02:13, 25.05 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  17% 662/4000 [00:36<02:23, 23.32 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  17% 666/4000 [00:37<02:41, 20.69 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  17% 670/4000 [00:37<02:23, 23.24 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  17% 674/4000 [00:37<02:24, 23.10 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  17% 678/4000 [00:37<02:20, 23.60 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  17% 682/4000 [00:37<02:06, 26.20 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  17% 686/4000 [00:37<02:08, 25.87 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  17% 690/4000 [00:38<02:12, 24.89 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  17% 694/4000 [00:38<02:02, 26.94 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  17% 698/4000 [00:38<01:53, 29.00 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18% 702/4000 [00:38<01:50, 29.87 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18% 706/4000 [00:38<01:55, 28.41 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18% 710/4000 [00:38<02:18, 23.84 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18% 714/4000 [00:39<02:43, 20.05 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18% 718/4000 [00:39<02:24, 22.70 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18% 722/4000 [00:39<02:18, 23.61 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18% 726/4000 [00:39<02:03, 26.53 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18% 730/4000 [00:39<01:54, 28.66 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18% 734/4000 [00:39<01:47, 30.43 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  18% 738/4000 [00:39<01:50, 29.53 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19% 742/4000 [00:40<02:00, 27.13 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19% 746/4000 [00:40<02:08, 25.36 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19% 750/4000 [00:40<02:39, 20.41 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19% 754/4000 [00:40<02:47, 19.37 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19% 758/4000 [00:41<02:52, 18.83 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19% 762/4000 [00:41<02:53, 18.71 examples/s]Using default parameters optimized on Brouhaha
# Map:  19% 764/4000 [00:41<03:01, 17.84 examples/s]Using default parameters optimized on Brouhaha
# Map:  19% 766/4000 [00:41<02:59, 18.07 examples/s]Using default parameters optimized on Brouhaha
# Map:  19% 768/4000 [00:41<03:04, 17.52 examples/s]Using default parameters optimized on Brouhaha
# Map:  19% 770/4000 [00:41<03:11, 16.87 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19% 774/4000 [00:41<02:56, 18.26 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  19% 778/4000 [00:42<02:29, 21.56 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  20% 782/4000 [00:42<02:35, 20.64 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  20% 786/4000 [00:42<02:44, 19.56 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  20% 790/4000 [00:42<02:21, 22.75 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  20% 794/4000 [00:42<02:38, 20.26 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  20% 798/4000 [00:43<02:56, 18.14 examples/s]Using default parameters optimized on Brouhaha
# Map:  20% 800/4000 [00:43<03:05, 17.26 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  20% 804/4000 [00:43<02:50, 18.76 examples/s]Using default parameters optimized on Brouhaha
# Map:  20% 806/4000 [00:43<02:48, 18.90 examples/s]Using default parameters optimized on Brouhaha
# Map:  20% 808/4000 [00:43<03:01, 17.55 examples/s]Using default parameters optimized on Brouhaha
# Map:  20% 810/4000 [00:43<03:07, 17.02 examples/s]Using default parameters optimized on Brouhaha
# Map:  20% 812/4000 [00:43<03:06, 17.14 examples/s]Using default parameters optimized on Brouhaha
# Map:  20% 814/4000 [00:44<03:19, 15.94 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  20% 818/4000 [00:44<02:57, 17.97 examples/s]Using default parameters optimized on Brouhaha
# Map:  20% 820/4000 [00:44<03:01, 17.52 examples/s]Using default parameters optimized on Brouhaha
# Map:  21% 822/4000 [00:44<03:01, 17.55 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  21% 826/4000 [00:44<03:03, 17.32 examples/s]Using default parameters optimized on Brouhaha
# Map:  21% 828/4000 [00:44<02:59, 17.72 examples/s]Using default parameters optimized on Brouhaha
# Map:  21% 830/4000 [00:44<03:03, 17.28 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  21% 834/4000 [00:45<03:35, 14.67 examples/s]Using default parameters optimized on Brouhaha
# Map:  21% 836/4000 [00:45<03:58, 13.26 examples/s]Using default parameters optimized on Brouhaha
# Map:  21% 838/4000 [00:45<04:19, 12.19 examples/s]Using default parameters optimized on Brouhaha
# Map:  21% 840/4000 [00:45<04:27, 11.80 examples/s]Using default parameters optimized on Brouhaha
# Map:  21% 842/4000 [00:46<04:15, 12.36 examples/s]Using default parameters optimized on Brouhaha
# Map:  21% 844/4000 [00:46<04:13, 12.45 examples/s]Using default parameters optimized on Brouhaha
# Map:  21% 846/4000 [00:46<04:09, 12.66 examples/s]Using default parameters optimized on Brouhaha
# Map:  21% 848/4000 [00:46<03:48, 13.79 examples/s]Using default parameters optimized on Brouhaha
# Map:  21% 850/4000 [00:46<03:38, 14.41 examples/s]Using default parameters optimized on Brouhaha
# Map:  21% 852/4000 [00:46<03:49, 13.72 examples/s]Using default parameters optimized on Brouhaha
# Map:  21% 854/4000 [00:46<03:54, 13.39 examples/s]Using default parameters optimized on Brouhaha
# Map:  21% 856/4000 [00:47<03:51, 13.56 examples/s]Using default parameters optimized on Brouhaha
# Map:  21% 858/4000 [00:47<03:45, 13.92 examples/s]Using default parameters optimized on Brouhaha
# Map:  22% 860/4000 [00:47<03:50, 13.61 examples/s]Using default parameters optimized on Brouhaha
# Map:  22% 862/4000 [00:47<03:41, 14.18 examples/s]Using default parameters optimized on Brouhaha
# Map:  22% 864/4000 [00:47<03:36, 14.49 examples/s]Using default parameters optimized on Brouhaha
# Map:  22% 866/4000 [00:47<03:20, 15.65 examples/s]Using default parameters optimized on Brouhaha
# Map:  22% 868/4000 [00:47<03:22, 15.43 examples/s]Using default parameters optimized on Brouhaha
# Map:  22% 870/4000 [00:47<03:41, 14.15 examples/s]Using default parameters optimized on Brouhaha
# Map:  22% 872/4000 [00:48<03:24, 15.30 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  22% 876/4000 [00:48<03:15, 15.99 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  22% 880/4000 [00:48<03:05, 16.85 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  22% 884/4000 [00:48<02:36, 19.88 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  22% 888/4000 [00:48<02:43, 18.98 examples/s]Using default parameters optimized on Brouhaha
# Map:  22% 890/4000 [00:49<02:51, 18.10 examples/s]Using default parameters optimized on Brouhaha
# Map:  22% 892/4000 [00:49<03:03, 16.95 examples/s]Using default parameters optimized on Brouhaha
# Map:  22% 894/4000 [00:49<02:56, 17.57 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  22% 898/4000 [00:49<02:43, 18.98 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  23% 902/4000 [00:49<02:40, 19.26 examples/s]Using default parameters optimized on Brouhaha
# Map:  23% 904/4000 [00:49<02:47, 18.44 examples/s]Using default parameters optimized on Brouhaha
# Map:  23% 906/4000 [00:49<03:03, 16.83 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  23% 910/4000 [00:50<02:38, 19.47 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  23% 914/4000 [00:50<02:30, 20.46 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  23% 918/4000 [00:50<02:30, 20.45 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  23% 922/4000 [00:50<02:30, 20.40 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  23% 926/4000 [00:50<02:35, 19.74 examples/s]Using default parameters optimized on Brouhaha
# Map:  23% 928/4000 [00:51<02:45, 18.55 examples/s]Using default parameters optimized on Brouhaha
# Map:  23% 930/4000 [00:51<02:50, 17.97 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  23% 934/4000 [00:51<02:39, 19.23 examples/s]Using default parameters optimized on Brouhaha
# Map:  23% 936/4000 [00:51<02:46, 18.45 examples/s]Using default parameters optimized on Brouhaha
# Map:  23% 938/4000 [00:51<03:01, 16.83 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  24% 942/4000 [00:51<02:59, 17.05 examples/s]Using default parameters optimized on Brouhaha
# Map:  24% 944/4000 [00:51<02:54, 17.48 examples/s]Using default parameters optimized on Brouhaha
# Map:  24% 946/4000 [00:52<03:00, 16.92 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  24% 950/4000 [00:52<02:48, 18.06 examples/s]Using default parameters optimized on Brouhaha
# Map:  24% 952/4000 [00:52<02:52, 17.68 examples/s]Using default parameters optimized on Brouhaha
# Map:  24% 954/4000 [00:52<02:58, 17.07 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  24% 958/4000 [00:52<02:30, 20.24 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  24% 962/4000 [00:52<02:50, 17.77 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  24% 966/4000 [00:53<02:31, 20.08 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  24% 970/4000 [00:53<02:17, 22.09 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  24% 974/4000 [00:53<02:22, 21.24 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  24% 978/4000 [00:53<02:29, 20.17 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  25% 982/4000 [00:53<02:28, 20.37 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  25% 986/4000 [00:54<02:36, 19.24 examples/s]Using default parameters optimized on Brouhaha
# Map:  25% 988/4000 [00:54<02:37, 19.17 examples/s]Using default parameters optimized on Brouhaha
# Map:  25% 990/4000 [00:54<02:39, 18.85 examples/s]Using default parameters optimized on Brouhaha
# Map:  25% 992/4000 [00:54<02:49, 17.74 examples/s]Using default parameters optimized on Brouhaha
# Map:  25% 994/4000 [00:54<02:45, 18.18 examples/s]Using default parameters optimized on Brouhaha
# Map:  25% 996/4000 [00:54<02:49, 17.68 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  25% 1000/4000 [00:54<02:37, 19.10 examples/s]Using default parameters optimized on Brouhaha
# Map:  25% 1002/4000 [00:55<02:55, 17.05 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  25% 1006/4000 [00:55<02:33, 19.56 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  25% 1010/4000 [00:55<02:22, 20.96 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  25% 1014/4000 [00:55<02:05, 23.82 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  25% 1018/4000 [00:55<02:24, 20.61 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  26% 1022/4000 [00:55<02:22, 20.85 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  26% 1026/4000 [00:56<02:19, 21.39 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  26% 1030/4000 [00:56<02:19, 21.34 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  26% 1034/4000 [00:56<02:34, 19.19 examples/s]Using default parameters optimized on Brouhaha
# Map:  26% 1036/4000 [00:56<02:48, 17.61 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  26% 1040/4000 [00:56<02:52, 17.15 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  26% 1044/4000 [00:57<03:06, 15.88 examples/s]Using default parameters optimized on Brouhaha
# Map:  26% 1046/4000 [00:57<03:27, 14.22 examples/s]Using default parameters optimized on Brouhaha
# Map:  26% 1048/4000 [00:57<03:35, 13.70 examples/s]Using default parameters optimized on Brouhaha
# Map:  26% 1050/4000 [00:57<03:56, 12.45 examples/s]Using default parameters optimized on Brouhaha
# Map:  26% 1052/4000 [00:57<04:01, 12.20 examples/s]Using default parameters optimized on Brouhaha
# Map:  26% 1054/4000 [00:58<03:59, 12.30 examples/s]Using default parameters optimized on Brouhaha
# Map:  26% 1056/4000 [00:58<04:07, 11.90 examples/s]Using default parameters optimized on Brouhaha
# Map:  26% 1058/4000 [00:58<03:56, 12.43 examples/s]Using default parameters optimized on Brouhaha
# Map:  26% 1060/4000 [00:58<03:52, 12.67 examples/s]Using default parameters optimized on Brouhaha
# Map:  27% 1062/4000 [00:58<03:50, 12.77 examples/s]Using default parameters optimized on Brouhaha
# Map:  27% 1064/4000 [00:58<04:02, 12.09 examples/s]Using default parameters optimized on Brouhaha
# Map:  27% 1066/4000 [00:59<04:00, 12.21 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  27% 1070/4000 [00:59<03:34, 13.65 examples/s]Using default parameters optimized on Brouhaha
# Map:  27% 1072/4000 [00:59<03:38, 13.42 examples/s]Using default parameters optimized on Brouhaha
# Map:  27% 1074/4000 [00:59<03:21, 14.50 examples/s]Using default parameters optimized on Brouhaha
# Map:  27% 1076/4000 [00:59<03:20, 14.57 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  27% 1080/4000 [00:59<02:55, 16.67 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  27% 1084/4000 [01:00<02:48, 17.33 examples/s]Using default parameters optimized on Brouhaha
# Map:  27% 1086/4000 [01:00<02:45, 17.60 examples/s]Using default parameters optimized on Brouhaha
# Map:  27% 1088/4000 [01:00<02:59, 16.23 examples/s]Using default parameters optimized on Brouhaha
# ...
# Map:  92% 3680/4000 [03:27<00:18, 17.41 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  92% 3684/4000 [03:28<00:16, 19.58 examples/s]Using default parameters optimized on Brouhaha
# Map:  92% 3686/4000 [03:28<00:18, 17.19 examples/s]Using default parameters optimized on Brouhaha
# Map:  92% 3688/4000 [03:28<00:19, 16.21 examples/s]Using default parameters optimized on Brouhaha
# Map:  92% 3690/4000 [03:28<00:18, 16.54 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  92% 3694/4000 [03:28<00:16, 19.08 examples/s]Using default parameters optimized on Brouhaha
# Map:  92% 3696/4000 [03:28<00:16, 18.08 examples/s]Using default parameters optimized on Brouhaha
# Map:  92% 3698/4000 [03:28<00:16, 17.80 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  93% 3702/4000 [03:29<00:16, 18.42 examples/s]Using default parameters optimized on Brouhaha
# Map:  93% 3704/4000 [03:29<00:16, 18.02 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  93% 3708/4000 [03:29<00:15, 19.03 examples/s]Using default parameters optimized on Brouhaha
# Map:  93% 3710/4000 [03:29<00:15, 18.28 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  93% 3714/4000 [03:29<00:15, 18.65 examples/s]Using default parameters optimized on Brouhaha
# Map:  93% 3716/4000 [03:29<00:15, 18.54 examples/s]Using default parameters optimized on Brouhaha
# Map:  93% 3718/4000 [03:30<00:16, 16.97 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  93% 3722/4000 [03:30<00:14, 18.95 examples/s]Using default parameters optimized on Brouhaha
# Map:  93% 3724/4000 [03:30<00:15, 17.43 examples/s]Using default parameters optimized on Brouhaha
# Map:  93% 3726/4000 [03:30<00:15, 17.64 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  93% 3730/4000 [03:30<00:14, 18.05 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  93% 3734/4000 [03:30<00:14, 18.80 examples/s]Using default parameters optimized on Brouhaha
# Map:  93% 3736/4000 [03:30<00:14, 18.64 examples/s]Using default parameters optimized on Brouhaha
# Map:  93% 3738/4000 [03:31<00:14, 17.50 examples/s]Using default parameters optimized on Brouhaha
# Map:  94% 3740/4000 [03:31<00:15, 16.79 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  94% 3744/4000 [03:31<00:13, 19.21 examples/s]Using default parameters optimized on Brouhaha
# Map:  94% 3746/4000 [03:31<00:13, 18.88 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  94% 3750/4000 [03:31<00:13, 18.50 examples/s]Using default parameters optimized on Brouhaha
# Map:  94% 3752/4000 [03:31<00:13, 18.55 examples/s]Using default parameters optimized on Brouhaha
# Map:  94% 3754/4000 [03:31<00:13, 18.63 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  94% 3758/4000 [03:32<00:12, 19.13 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  94% 3762/4000 [03:32<00:12, 18.58 examples/s]Using default parameters optimized on Brouhaha
# Map:  94% 3764/4000 [03:32<00:13, 17.81 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  94% 3768/4000 [03:32<00:11, 20.01 examples/s]Using default parameters optimized on Brouhaha
# Map:  94% 3770/4000 [03:32<00:11, 19.70 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  94% 3774/4000 [03:32<00:10, 20.57 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  94% 3778/4000 [03:33<00:11, 18.74 examples/s]Using default parameters optimized on Brouhaha
# Map:  94% 3780/4000 [03:33<00:12, 17.21 examples/s]Using default parameters optimized on Brouhaha
# Map:  95% 3782/4000 [03:33<00:12, 17.16 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  95% 3786/4000 [03:33<00:12, 17.67 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  95% 3790/4000 [03:33<00:11, 17.93 examples/s]Using default parameters optimized on Brouhaha
# Map:  95% 3792/4000 [03:34<00:12, 17.02 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  95% 3796/4000 [03:34<00:11, 18.01 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  95% 3800/4000 [03:34<00:09, 20.07 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  95% 3804/4000 [03:34<00:10, 19.07 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  95% 3808/4000 [03:34<00:09, 19.97 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  95% 3812/4000 [03:34<00:08, 22.99 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  95% 3816/4000 [03:35<00:07, 23.35 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  96% 3820/4000 [03:35<00:07, 23.00 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  96% 3824/4000 [03:35<00:08, 20.10 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  96% 3828/4000 [03:35<00:10, 16.48 examples/s]Using default parameters optimized on Brouhaha
# Map:  96% 3830/4000 [03:35<00:10, 16.37 examples/s]Using default parameters optimized on Brouhaha
# Map:  96% 3832/4000 [03:36<00:10, 15.76 examples/s]Using default parameters optimized on Brouhaha
# Map:  96% 3834/4000 [03:36<00:10, 15.47 examples/s]Using default parameters optimized on Brouhaha
# Map:  96% 3836/4000 [03:36<00:11, 13.79 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  96% 3840/4000 [03:36<00:10, 14.69 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  96% 3844/4000 [03:36<00:10, 15.48 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  96% 3848/4000 [03:37<00:10, 14.67 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  96% 3852/4000 [03:37<00:09, 15.66 examples/s]Using default parameters optimized on Brouhaha
# Map:  96% 3854/4000 [03:37<00:09, 15.27 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  96% 3858/4000 [03:37<00:07, 18.38 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  97% 3862/4000 [03:37<00:07, 19.65 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  97% 3866/4000 [03:38<00:06, 21.71 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  97% 3870/4000 [03:38<00:06, 20.15 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  97% 3874/4000 [03:38<00:05, 21.46 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  97% 3878/4000 [03:38<00:06, 20.09 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  97% 3882/4000 [03:38<00:05, 20.06 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  97% 3886/4000 [03:38<00:04, 23.28 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  97% 3890/4000 [03:39<00:04, 23.45 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  97% 3894/4000 [03:39<00:04, 22.79 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  97% 3898/4000 [03:39<00:04, 22.14 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  98% 3902/4000 [03:39<00:04, 23.15 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  98% 3906/4000 [03:39<00:04, 22.35 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  98% 3910/4000 [03:40<00:03, 22.70 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  98% 3914/4000 [03:40<00:04, 20.73 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  98% 3918/4000 [03:40<00:03, 22.99 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  98% 3922/4000 [03:40<00:03, 24.04 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  98% 3926/4000 [03:40<00:03, 24.06 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  98% 3930/4000 [03:40<00:02, 24.46 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  98% 3934/4000 [03:41<00:02, 26.12 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  98% 3938/4000 [03:41<00:02, 25.74 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  99% 3942/4000 [03:41<00:02, 25.11 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  99% 3946/4000 [03:41<00:02, 22.37 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  99% 3950/4000 [03:41<00:02, 21.88 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  99% 3954/4000 [03:41<00:02, 22.97 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  99% 3958/4000 [03:42<00:01, 21.93 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  99% 3962/4000 [03:42<00:01, 22.83 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  99% 3966/4000 [03:42<00:01, 22.09 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  99% 3970/4000 [03:42<00:01, 24.62 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  99% 3974/4000 [03:42<00:01, 23.91 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map:  99% 3978/4000 [03:42<00:00, 22.70 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map: 100% 3982/4000 [03:43<00:00, 21.32 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map: 100% 3986/4000 [03:43<00:00, 23.52 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map: 100% 3990/4000 [03:43<00:00, 22.88 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map: 100% 3994/4000 [03:43<00:00, 22.94 examples/s]Using default parameters optimized on Brouhaha
# Using default parameters optimized on Brouhaha
# Map: 100% 3998/4000 [03:43<00:00, 21.78 examples/s]Using default parameters optimized on Brouhaha
# Map: 100% 4000/4000 [03:43<00:00, 17.86 examples/s]
# Compute speaking rate
# Map (num_proc=2):   0% 0/4000 [00:00<?, ? examples/s]2024-04-30 13:48:28.805392: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-30 13:48:28.805458: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-30 13:48:28.813698: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-30 13:48:28.839076: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-30 13:48:28.839131: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-30 13:48:28.840792: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-30 13:48:28.993941: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-30 13:48:28.993996: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-30 13:48:28.998854: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-30 13:48:31.318734: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-04-30 13:48:31.912391: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-04-30 13:48:32.196200: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/pyannote/audio/core/io.py:43: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("soundfile")
# /usr/local/lib/python3.10/dist-packages/pyannote/audio/core/io.py:43: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("soundfile")
# /usr/local/lib/python3.10/dist-packages/pyannote/audio/core/io.py:43: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("soundfile")
# Map (num_proc=2): 100% 4000/4000 [01:37<00:00, 40.88 examples/s]
# Pushing to the hub...
# Uploading the dataset shards:   0% 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0% 0/4 [00:00<?, ?ba/s]
# Creating parquet from Arrow format: 100% 4/4 [00:00<00:00, 34.19ba/s]
# Uploading the dataset shards: 100% 1/1 [00:00<00:00,  2.66it/s]
# README.md: 100% 728/728 [00:00<00:00, 3.07MB/s]

# %% [markdown]
# The whole process took under 10mn!
#
# The resulting dataset will be pushed to the HuggingFace hub under your HuggingFace handle. Mine was push to [ylacombe/jenny-tts-tags-6h](https://huggingface.co/datasets/ylacombe/jenny-tts-tags-6h).
#
# Let's see what the new dataset looks like:

# %%
from datasets import load_dataset
dataset = load_dataset("ylacombe/jenny-tts-tags-6h")
print("SNR 1st sample", dataset["train"][0]["snr"])
print("C50 2nd sample", dataset["train"][0]["c50"])
del dataset
# Out:
# Downloading readme:   0%|          | 0.00/609 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/958k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/4000 [00:00<?, ? examples/s]
# SNR 1st sample 54.890892028808594
# C50 2nd sample 59.73095703125

# %% [markdown]
# As you can see, the current annotations are continuous variables. To use it with Parler-TTS, we need to convert it to textual description, something that the two next steps will take care of.

# %% [markdown]
# ### 2. Map annotations to text bins
#
# Since the ultimate goal here is to fine-tune the [Parler-TTS v0.1 checkpoint](https://huggingface.co/parler-tts/parler_tts_mini_v0.1) on the Jenny dataset, we want to stay consistent with the text bins of the datasets on which the latter model was trained.
#
# This is easy to do thanks to the following:

# %%
# !python ./scripts/metadata_to_text.py \
    "ylacombe/jenny-tts-tags-6h" \
    --repo_id "jenny-tts-tags-6h" \
    --configuration "default" \
    --cpu_num_workers 2 \
    --path_to_bin_edges "./examples/tags_to_annotations/v01_bin_edges.json" \
    --avoid_pitch_computation
# Out:
# Already computed bin edges have been passed for speaking_rate. Will use: [3.508771929824561, 6.187242299296628, 8.865712668768696, 11.544183038240764, 14.22265340771283, 16.901123777184896, 19.579594146656966, 22.258064516129032].
# Map (num_proc=2): 100% 4000/4000 [00:03<00:00, 1202.34 examples/s]
# Already computed bin edges have been passed for noise. Will use: [50.0, 53.460838317871094, 56.92167663574219, 60.38251495361328, 63.843353271484375, 67.30419158935547, 70.76502990722656, 74.22586822509766].
# Map (num_proc=2): 100% 4000/4000 [00:03<00:00, 1193.89 examples/s]
# Already computed bin edges have been passed for reverberation. Will use: [30.498437881469727, 34.706024169921875, 38.91361045837402, 43.12119674682617, 47.32878303527832, 51.53636932373047, 55.74395561218262, 59.951541900634766].
# Map (num_proc=2): 100% 4000/4000 [00:03<00:00, 1048.53 examples/s]
# Already computed bin edges have been passed for speech_monotony. Will use: [0.0, 17.430070059640066, 34.86014011928013, 52.2902101789202, 69.72028023856026, 87.15035029820032, 104.5804203578404, 122.01049041748047].
# Map (num_proc=2): 100% 4000/4000 [00:03<00:00, 1026.24 examples/s]
# Uploading the dataset shards:   0% 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format: 100% 4/4 [00:00<00:00, 121.58ba/s]
# Uploading the dataset shards: 100% 1/1 [00:00<00:00,  3.55it/s]
# README.md: 100% 609/609 [00:00<00:00, 4.04MB/s]

# %% [markdown]
# Thanks to [`v01_bin_edges.json`](https://github.com/huggingface/dataspeech/blob/main/examples/tags_to_annotations/v01_bin_edges.json), we don't need to recompute bins from scratch and the above script takes a few seconds.
#
# The resulting dataset will be pushed to the HuggingFace hub under your HuggingFace handle. Mine was push to [ylacombe/jenny-tts-tags-6h](https://huggingface.co/datasets/ylacombe/jenny-tts-tags-6h).
#
# You can notice that text bins such as `quite noisy`, `very fast` have been added to the samples.

# %%
from datasets import load_dataset
dataset = load_dataset("ylacombe/jenny-tts-tags-6h")
print("Noise 1st sample:", dataset["train"][0]["noise"])
print("Speaking rate 2nd sample:", dataset["train"][0]["speaking_rate"])
del dataset
# Out:
# Downloading readme:   0%|          | 0.00/728 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/935k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/4000 [00:00<?, ? examples/s]
# Noise 1st sample: quite noisy
# Speaking rate 2nd sample: quite fast

# %% [markdown]
# ### 3. Create natural language descriptions from those text bins
#
# Now that we have text bins associated to the Jenny dataset, the next step is to create natural language descriptions out of the few created features.
#
# Here, we decided to create prompts that use the name `Jenny`, prompts that'll look like the following:
# `In a very expressive voice, Jenny pronounces her words incredibly slowly. There's some background noise in this room with a bit of echo'`
#
# This step generally demands more resources and times and should use one or many GPUs.
#
# The following command shows how to do it using the [2B version of the Gemma model from Google](https://huggingface.co/google/gemma-2b-it), which should run in about 15 minutes in this Colab free T4.
#
#
# As usual, we precise the dataset name and configuration we want to annotate. `model_name_or_path` should point to a `transformers` model for prompt annotation. You can find a list of such models [here](https://huggingface.co/models?pipeline_tag=text-generation&library=transformers&sort=trending).
#
# **Note** how we've been able to specify that the dataset is mono-speaker and that we should name the voice Jenny thanks to the flags:
#
#
# `--speaker_name "Jenny" --is_single_speaker`.

# %%
# !python ./scripts/run_prompt_creation.py \
  --speaker_name "Jenny" \
  --is_single_speaker \
  --dataset_name "ylacombe/jenny-tts-tags-6h" \
  --output_dir "./tmp_jenny" \
  --dataset_config_name "default" \
  --model_name_or_path "google/gemma-2b-it" \
  --per_device_eval_batch_size 12 \
  --attn_implementation "sdpa" \
  --dataloader_num_workers 2 \
  --push_to_hub \
  --hub_dataset_id "jenny-tts-6h-tagged" \
  --preprocessing_num_workers 2
# Out:
# 04/30/2024 14:17:59 - INFO - __main__ - *** Load annotated dataset ***
# 04/30/2024 14:18:01 - INFO - __main__ - *** Load pretrained model ***
# Gemma's activation function should be approximate GeLU and not exact GeLU.
# Changing the activation function to `gelu_pytorch_tanh`.if you want to use the legacy `gelu`, edit the `model.config` to set `hidden_activation=gelu`   instead of `hidden_act`. See https://github.com/huggingface/transformers/pull/29402 for more details.
# Loading checkpoint shards: 100% 2/2 [00:14<00:00,  7.41s/it]
#  ... :   0% 0/334 [00:00<?, ?it/s]04/30/2024 14:18:21 - INFO - __main__ - Resuming train from step 334
#  ... : 100% 334/334 [00:00<00:00, 897.60it/s]/usr/local/lib/python3.10/dist-packages/multiprocess/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
# Postprocessing dataset (num_proc=2):   0% 0/4000 [00:00<?, ? examples/s]2024-04-30 14:18:25.911693: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-30 14:18:25.911693: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-30 14:18:25.911751: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-30 14:18:25.911751: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-30 14:18:26.038880: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-30 14:18:26.038880: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-30 14:18:28.676988: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-04-30 14:18:28.676988: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#
# Postprocessing dataset (num_proc=2):   0% 1/4000 [00:08<9:36:02,  8.64s/ examples]
# Postprocessing dataset (num_proc=2):   0% 9/4000 [00:08<47:04,  1.41 examples/s]
# Postprocessing dataset (num_proc=2):   0% 18/4000 [00:08<19:23,  3.42 examples/s]
# Postprocessing dataset (num_proc=2):   1% 26/4000 [00:08<11:26,  5.79 examples/s]
# Postprocessing dataset (num_proc=2):   1% 38/4000 [00:09<06:13, 10.60 examples/s]
# Postprocessing dataset (num_proc=2):   1% 47/4000 [00:09<04:24, 14.96 examples/s]
# Postprocessing dataset (num_proc=2):   1% 57/4000 [00:09<03:09, 20.86 examples/s]
#  ... : 100% 334/334 [00:10<00:00, 897.60it/s]
# Postprocessing dataset (num_proc=2):   2% 79/4000 [00:09<01:46, 36.90 examples/s]
# Postprocessing dataset (num_proc=2):   2% 93/4000 [00:09<01:19, 49.31 examples/s]
# Postprocessing dataset (num_proc=2):   3% 103/4000 [00:09<01:10, 55.49 examples/s]
# Postprocessing dataset (num_proc=2):   3% 117/4000 [00:09<00:56, 68.44 examples/s]
# Postprocessing dataset (num_proc=2):   3% 128/4000 [00:10<00:55, 70.07 examples/s]
# Postprocessing dataset (num_proc=2):   4% 140/4000 [00:10<00:50, 76.06 examples/s]
# Postprocessing dataset (num_proc=2):   4% 153/4000 [00:10<00:44, 85.86 examples/s]
# Postprocessing dataset (num_proc=2):   4% 166/4000 [00:10<00:42, 89.62 examples/s]
# Postprocessing dataset (num_proc=2):   4% 177/4000 [00:10<00:42, 90.55 examples/s]
# Postprocessing dataset (num_proc=2):   5% 191/4000 [00:10<00:38, 99.29 examples/s]
# Postprocessing dataset (num_proc=2):   5% 208/4000 [00:10<00:33, 113.44 examples/s]
# Postprocessing dataset (num_proc=2):   6% 222/4000 [00:10<00:32, 114.68 examples/s]
# Postprocessing dataset (num_proc=2):   6% 238/4000 [00:11<00:30, 121.52 examples/s]
# Postprocessing dataset (num_proc=2):   6% 254/4000 [00:11<00:28, 130.56 examples/s]
# Postprocessing dataset (num_proc=2):   7% 272/4000 [00:11<00:27, 137.22 examples/s]
# Postprocessing dataset (num_proc=2):   7% 288/4000 [00:11<00:26, 142.11 examples/s]
# Postprocessing dataset (num_proc=2):   8% 304/4000 [00:11<00:25, 145.46 examples/s]
# Postprocessing dataset (num_proc=2):   8% 320/4000 [00:11<00:25, 144.20 examples/s]
# Postprocessing dataset (num_proc=2):   8% 337/4000 [00:11<00:25, 146.04 examples/s]
# Postprocessing dataset (num_proc=2):   9% 353/4000 [00:11<00:24, 148.80 examples/s]
# Postprocessing dataset (num_proc=2):   9% 369/4000 [00:11<00:24, 145.34 examples/s]
# Postprocessing dataset (num_proc=2):  10% 386/4000 [00:12<00:24, 147.36 examples/s]
# Postprocessing dataset (num_proc=2):  10% 402/4000 [00:12<00:24, 149.61 examples/s]
# Postprocessing dataset (num_proc=2):  10% 419/4000 [00:12<00:23, 149.60 examples/s]
# Postprocessing dataset (num_proc=2):  11% 437/4000 [00:12<00:23, 152.39 examples/s]
# Postprocessing dataset (num_proc=2):  11% 453/4000 [00:12<00:23, 152.82 examples/s]
# Postprocessing dataset (num_proc=2):  12% 470/4000 [00:12<00:22, 156.09 examples/s]
# Postprocessing dataset (num_proc=2):  12% 486/4000 [00:12<00:22, 156.85 examples/s]
# Postprocessing dataset (num_proc=2):  13% 502/4000 [00:12<00:22, 156.15 examples/s]
# Postprocessing dataset (num_proc=2):  13% 519/4000 [00:12<00:22, 151.81 examples/s]
# Postprocessing dataset (num_proc=2):  13% 538/4000 [00:13<00:22, 155.97 examples/s]
# Postprocessing dataset (num_proc=2):  14% 554/4000 [00:13<00:22, 156.61 examples/s]
# Postprocessing dataset (num_proc=2):  14% 570/4000 [00:13<00:22, 153.84 examples/s]
# Postprocessing dataset (num_proc=2):  15% 587/4000 [00:13<00:21, 157.40 examples/s]
# Postprocessing dataset (num_proc=2):  15% 603/4000 [00:13<00:22, 153.64 examples/s]
# Postprocessing dataset (num_proc=2):  15% 619/4000 [00:13<00:22, 152.44 examples/s]
# Postprocessing dataset (num_proc=2):  16% 637/4000 [00:13<00:22, 150.43 examples/s]
# Postprocessing dataset (num_proc=2):  16% 654/4000 [00:13<00:22, 148.56 examples/s]
# Postprocessing dataset (num_proc=2):  17% 671/4000 [00:13<00:22, 149.44 examples/s]
# Postprocessing dataset (num_proc=2):  17% 688/4000 [00:14<00:22, 146.79 examples/s]
# Postprocessing dataset (num_proc=2):  18% 704/4000 [00:14<00:22, 148.17 examples/s]
# Postprocessing dataset (num_proc=2):  18% 722/4000 [00:14<00:21, 151.66 examples/s]
# Postprocessing dataset (num_proc=2):  18% 740/4000 [00:14<00:21, 154.47 examples/s]
# Postprocessing dataset (num_proc=2):  19% 757/4000 [00:14<00:20, 156.49 examples/s]
# Postprocessing dataset (num_proc=2):  19% 775/4000 [00:14<00:20, 155.59 examples/s]
# Postprocessing dataset (num_proc=2):  20% 791/4000 [00:14<00:20, 155.69 examples/s]
# Postprocessing dataset (num_proc=2):  20% 807/4000 [00:14<00:20, 154.05 examples/s]
# Postprocessing dataset (num_proc=2):  21% 823/4000 [00:14<00:20, 154.09 examples/s]
# Postprocessing dataset (num_proc=2):  21% 841/4000 [00:14<00:20, 154.95 examples/s]
# Postprocessing dataset (num_proc=2):  22% 861/4000 [00:15<00:20, 149.67 examples/s]
# Postprocessing dataset (num_proc=2):  22% 878/4000 [00:15<00:21, 148.19 examples/s]
# Postprocessing dataset (num_proc=2):  22% 896/4000 [00:15<00:19, 155.40 examples/s]
# Postprocessing dataset (num_proc=2):  23% 912/4000 [00:15<00:20, 152.69 examples/s]
# Postprocessing dataset (num_proc=2):  23% 929/4000 [00:15<00:19, 156.81 examples/s]
# Postprocessing dataset (num_proc=2):  24% 945/4000 [00:15<00:19, 154.91 examples/s]
# Postprocessing dataset (num_proc=2):  24% 961/4000 [00:15<00:20, 148.06 examples/s]
# Postprocessing dataset (num_proc=2):  24% 977/4000 [00:15<00:20, 145.52 examples/s]
# Postprocessing dataset (num_proc=2):  25% 993/4000 [00:16<00:20, 143.35 examples/s]
# Postprocessing dataset (num_proc=2):  25% 1008/4000 [00:16<00:21, 142.18 examples/s]
# Postprocessing dataset (num_proc=2):  26% 1025/4000 [00:16<00:20, 144.60 examples/s]
# Postprocessing dataset (num_proc=2):  26% 1041/4000 [00:16<00:20, 147.75 examples/s]
# Postprocessing dataset (num_proc=2):  26% 1057/4000 [00:16<00:19, 150.24 examples/s]
# Postprocessing dataset (num_proc=2):  27% 1077/4000 [00:16<00:18, 154.06 examples/s]
# Postprocessing dataset (num_proc=2):  27% 1094/4000 [00:16<00:19, 150.33 examples/s]
# Postprocessing dataset (num_proc=2):  28% 1111/4000 [00:16<00:19, 149.15 examples/s]
# Postprocessing dataset (num_proc=2):  28% 1127/4000 [00:16<00:18, 151.77 examples/s]
# Postprocessing dataset (num_proc=2):  29% 1144/4000 [00:17<00:18, 154.46 examples/s]
# Postprocessing dataset (num_proc=2):  29% 1160/4000 [00:17<00:18, 152.30 examples/s]
# Postprocessing dataset (num_proc=2):  29% 1178/4000 [00:17<00:18, 154.62 examples/s]
# Postprocessing dataset (num_proc=2):  30% 1195/4000 [00:17<00:18, 153.63 examples/s]
# Postprocessing dataset (num_proc=2):  30% 1211/4000 [00:17<00:18, 153.85 examples/s]
# Postprocessing dataset (num_proc=2):  31% 1227/4000 [00:17<00:17, 154.65 examples/s]
# Postprocessing dataset (num_proc=2):  31% 1246/4000 [00:17<00:17, 153.90 examples/s]
# Postprocessing dataset (num_proc=2):  32% 1264/4000 [00:17<00:17, 159.06 examples/s]
# Postprocessing dataset (num_proc=2):  32% 1281/4000 [00:17<00:17, 152.96 examples/s]
# Postprocessing dataset (num_proc=2):  32% 1298/4000 [00:18<00:17, 157.29 examples/s]
# Postprocessing dataset (num_proc=2):  33% 1314/4000 [00:18<00:17, 151.49 examples/s]
# Postprocessing dataset (num_proc=2):  33% 1330/4000 [00:18<00:17, 150.44 examples/s]
# Postprocessing dataset (num_proc=2):  34% 1348/4000 [00:18<00:17, 153.60 examples/s]
# Postprocessing dataset (num_proc=2):  34% 1364/4000 [00:18<00:17, 150.03 examples/s]
# Postprocessing dataset (num_proc=2):  35% 1383/4000 [00:18<00:17, 150.67 examples/s]
# Postprocessing dataset (num_proc=2):  35% 1399/4000 [00:18<00:17, 152.68 examples/s]
# Postprocessing dataset (num_proc=2):  35% 1415/4000 [00:18<00:17, 152.03 examples/s]
# Postprocessing dataset (num_proc=2):  36% 1434/4000 [00:18<00:16, 152.57 examples/s]
# Postprocessing dataset (num_proc=2):  36% 1452/4000 [00:19<00:16, 152.56 examples/s]
# Postprocessing dataset (num_proc=2):  37% 1469/4000 [00:19<00:16, 156.80 examples/s]
# Postprocessing dataset (num_proc=2):  37% 1485/4000 [00:19<00:16, 154.36 examples/s]
# Postprocessing dataset (num_proc=2):  38% 1502/4000 [00:19<00:16, 151.75 examples/s]
# Postprocessing dataset (num_proc=2):  38% 1520/4000 [00:19<00:16, 153.07 examples/s]
# Postprocessing dataset (num_proc=2):  38% 1539/4000 [00:19<00:16, 153.44 examples/s]
# Postprocessing dataset (num_proc=2):  39% 1557/4000 [00:19<00:15, 153.39 examples/s]
# Postprocessing dataset (num_proc=2):  39% 1575/4000 [00:19<00:15, 155.54 examples/s]
# Postprocessing dataset (num_proc=2):  40% 1593/4000 [00:19<00:15, 154.87 examples/s]
# Postprocessing dataset (num_proc=2):  40% 1609/4000 [00:20<00:15, 151.63 examples/s]
# Postprocessing dataset (num_proc=2):  41% 1628/4000 [00:20<00:15, 155.54 examples/s]
# Postprocessing dataset (num_proc=2):  41% 1644/4000 [00:20<00:15, 151.01 examples/s]
# Postprocessing dataset (num_proc=2):  42% 1661/4000 [00:20<00:15, 151.44 examples/s]
# Postprocessing dataset (num_proc=2):  42% 1678/4000 [00:20<00:15, 152.98 examples/s]
# Postprocessing dataset (num_proc=2):  42% 1696/4000 [00:20<00:14, 155.40 examples/s]
# Postprocessing dataset (num_proc=2):  43% 1712/4000 [00:20<00:15, 145.53 examples/s]
# Postprocessing dataset (num_proc=2):  43% 1728/4000 [00:20<00:16, 135.39 examples/s]
# Postprocessing dataset (num_proc=2):  44% 1743/4000 [00:21<00:18, 122.01 examples/s]
# Postprocessing dataset (num_proc=2):  44% 1757/4000 [00:21<00:19, 116.33 examples/s]
# Postprocessing dataset (num_proc=2):  44% 1769/4000 [00:21<00:20, 111.46 examples/s]
# Postprocessing dataset (num_proc=2):  45% 1781/4000 [00:21<00:20, 108.03 examples/s]
# Postprocessing dataset (num_proc=2):  45% 1794/4000 [00:21<00:19, 110.51 examples/s]
# Postprocessing dataset (num_proc=2):  45% 1806/4000 [00:21<00:21, 100.11 examples/s]
# Postprocessing dataset (num_proc=2):  45% 1818/4000 [00:21<00:22, 97.11 examples/s]
# Postprocessing dataset (num_proc=2):  46% 1828/4000 [00:21<00:22, 95.69 examples/s]
# Postprocessing dataset (num_proc=2):  46% 1838/4000 [00:22<00:23, 93.96 examples/s]
# Postprocessing dataset (num_proc=2):  46% 1849/4000 [00:22<00:23, 90.53 examples/s]
# Postprocessing dataset (num_proc=2):  46% 1859/4000 [00:22<00:24, 87.24 examples/s]
# Postprocessing dataset (num_proc=2):  47% 1869/4000 [00:22<00:26, 81.56 examples/s]
# Postprocessing dataset (num_proc=2):  47% 1881/4000 [00:22<00:24, 86.48 examples/s]
# Postprocessing dataset (num_proc=2):  47% 1894/4000 [00:22<00:23, 89.77 examples/s]
# Postprocessing dataset (num_proc=2):  48% 1906/4000 [00:22<00:22, 91.35 examples/s]
# Postprocessing dataset (num_proc=2):  48% 1922/4000 [00:22<00:20, 103.60 examples/s]
# Postprocessing dataset (num_proc=2):  48% 1934/4000 [00:23<00:20, 101.54 examples/s]
# Postprocessing dataset (num_proc=2):  49% 1948/4000 [00:23<00:20, 102.00 examples/s]
# Postprocessing dataset (num_proc=2):  49% 1959/4000 [00:23<00:20, 98.93 examples/s]
# Postprocessing dataset (num_proc=2):  49% 1971/4000 [00:23<00:20, 100.78 examples/s]
# Postprocessing dataset (num_proc=2):  50% 1983/4000 [00:23<00:23, 84.41 examples/s]
# Postprocessing dataset (num_proc=2):  50% 1994/4000 [00:23<00:23, 85.18 examples/s]
# Postprocessing dataset (num_proc=2):  50% 2003/4000 [00:23<00:24, 80.97 examples/s]
# Postprocessing dataset (num_proc=2):  51% 2021/4000 [00:24<00:20, 97.29 examples/s]
# Postprocessing dataset (num_proc=2):  51% 2035/4000 [00:24<00:18, 104.92 examples/s]
# Postprocessing dataset (num_proc=2):  51% 2051/4000 [00:24<00:16, 117.52 examples/s]
# Postprocessing dataset (num_proc=2):  52% 2068/4000 [00:24<00:15, 126.99 examples/s]
# Postprocessing dataset (num_proc=2):  52% 2085/4000 [00:24<00:14, 132.74 examples/s]
# Postprocessing dataset (num_proc=2):  53% 2101/4000 [00:24<00:14, 133.28 examples/s]
# Postprocessing dataset (num_proc=2):  53% 2117/4000 [00:24<00:14, 134.46 examples/s]
# Postprocessing dataset (num_proc=2):  53% 2133/4000 [00:24<00:13, 139.52 examples/s]
# Postprocessing dataset (num_proc=2):  54% 2150/4000 [00:24<00:12, 145.29 examples/s]
# Postprocessing dataset (num_proc=2):  54% 2166/4000 [00:24<00:12, 148.91 examples/s]
# Postprocessing dataset (num_proc=2):  55% 2183/4000 [00:25<00:12, 148.99 examples/s]
# Postprocessing dataset (num_proc=2):  55% 2200/4000 [00:25<00:12, 146.48 examples/s]
# Postprocessing dataset (num_proc=2):  55% 2219/4000 [00:25<00:11, 149.28 examples/s]
# Postprocessing dataset (num_proc=2):  56% 2236/4000 [00:25<00:11, 150.10 examples/s]
# Postprocessing dataset (num_proc=2):  56% 2252/4000 [00:25<00:11, 150.72 examples/s]
# Postprocessing dataset (num_proc=2):  57% 2271/4000 [00:25<00:11, 155.72 examples/s]
# Postprocessing dataset (num_proc=2):  57% 2288/4000 [00:25<00:10, 156.33 examples/s]
# Postprocessing dataset (num_proc=2):  58% 2305/4000 [00:25<00:10, 159.34 examples/s]
# Postprocessing dataset (num_proc=2):  58% 2323/4000 [00:26<00:10, 157.83 examples/s]
# Postprocessing dataset (num_proc=2):  58% 2339/4000 [00:26<00:10, 155.52 examples/s]
# Postprocessing dataset (num_proc=2):  59% 2358/4000 [00:26<00:10, 159.47 examples/s]
# Postprocessing dataset (num_proc=2):  59% 2376/4000 [00:26<00:10, 157.31 examples/s]
# Postprocessing dataset (num_proc=2):  60% 2392/4000 [00:26<00:10, 149.60 examples/s]
# Postprocessing dataset (num_proc=2):  60% 2408/4000 [00:26<00:10, 150.43 examples/s]
# Postprocessing dataset (num_proc=2):  61% 2425/4000 [00:26<00:10, 154.88 examples/s]
# Postprocessing dataset (num_proc=2):  61% 2442/4000 [00:26<00:10, 155.57 examples/s]
# Postprocessing dataset (num_proc=2):  62% 2460/4000 [00:26<00:09, 156.21 examples/s]
# Postprocessing dataset (num_proc=2):  62% 2478/4000 [00:27<00:09, 156.67 examples/s]
# Postprocessing dataset (num_proc=2):  62% 2495/4000 [00:27<00:10, 149.51 examples/s]
# Postprocessing dataset (num_proc=2):  63% 2511/4000 [00:27<00:10, 145.73 examples/s]
# Postprocessing dataset (num_proc=2):  63% 2528/4000 [00:27<00:09, 147.29 examples/s]
# Postprocessing dataset (num_proc=2):  64% 2545/4000 [00:27<00:09, 151.56 examples/s]
# Postprocessing dataset (num_proc=2):  64% 2561/4000 [00:27<00:09, 150.93 examples/s]
# Postprocessing dataset (num_proc=2):  65% 2581/4000 [00:27<00:09, 154.94 examples/s]
# Postprocessing dataset (num_proc=2):  65% 2597/4000 [00:27<00:09, 154.78 examples/s]
# Postprocessing dataset (num_proc=2):  65% 2613/4000 [00:27<00:08, 155.70 examples/s]
# Postprocessing dataset (num_proc=2):  66% 2630/4000 [00:28<00:08, 154.19 examples/s]
# Postprocessing dataset (num_proc=2):  66% 2648/4000 [00:28<00:09, 150.17 examples/s]
# Postprocessing dataset (num_proc=2):  67% 2665/4000 [00:28<00:08, 153.85 examples/s]
# Postprocessing dataset (num_proc=2):  67% 2684/4000 [00:28<00:08, 157.93 examples/s]
# Postprocessing dataset (num_proc=2):  68% 2700/4000 [00:28<00:08, 155.62 examples/s]
# Postprocessing dataset (num_proc=2):  68% 2716/4000 [00:28<00:08, 149.30 examples/s]
# Postprocessing dataset (num_proc=2):  68% 2733/4000 [00:28<00:08, 149.80 examples/s]
# Postprocessing dataset (num_proc=2):  69% 2750/4000 [00:28<00:08, 154.62 examples/s]
# Postprocessing dataset (num_proc=2):  69% 2768/4000 [00:28<00:07, 159.05 examples/s]
# Postprocessing dataset (num_proc=2):  70% 2785/4000 [00:29<00:07, 155.10 examples/s]
# Postprocessing dataset (num_proc=2):  70% 2802/4000 [00:29<00:07, 153.97 examples/s]
# Postprocessing dataset (num_proc=2):  70% 2819/4000 [00:29<00:07, 153.27 examples/s]
# Postprocessing dataset (num_proc=2):  71% 2835/4000 [00:29<00:07, 153.40 examples/s]
# Postprocessing dataset (num_proc=2):  71% 2852/4000 [00:29<00:07, 157.52 examples/s]
# Postprocessing dataset (num_proc=2):  72% 2868/4000 [00:29<00:07, 155.71 examples/s]
# Postprocessing dataset (num_proc=2):  72% 2888/4000 [00:29<00:07, 142.39 examples/s]
# Postprocessing dataset (num_proc=2):  73% 2905/4000 [00:29<00:07, 148.39 examples/s]
# Postprocessing dataset (num_proc=2):  73% 2921/4000 [00:29<00:07, 150.65 examples/s]
# Postprocessing dataset (num_proc=2):  73% 2937/4000 [00:30<00:07, 149.57 examples/s]
# Postprocessing dataset (num_proc=2):  74% 2955/4000 [00:30<00:06, 157.20 examples/s]
# Postprocessing dataset (num_proc=2):  74% 2972/4000 [00:30<00:06, 156.19 examples/s]
# Postprocessing dataset (num_proc=2):  75% 2988/4000 [00:30<00:06, 152.90 examples/s]
# Postprocessing dataset (num_proc=2):  75% 3004/4000 [00:30<00:06, 150.49 examples/s]
# Postprocessing dataset (num_proc=2):  76% 3020/4000 [00:30<00:06, 148.86 examples/s]
# Postprocessing dataset (num_proc=2):  76% 3038/4000 [00:30<00:06, 144.07 examples/s]
# Postprocessing dataset (num_proc=2):  76% 3054/4000 [00:30<00:06, 143.76 examples/s]
# Postprocessing dataset (num_proc=2):  77% 3070/4000 [00:30<00:06, 144.88 examples/s]
# Postprocessing dataset (num_proc=2):  77% 3086/4000 [00:31<00:06, 147.87 examples/s]
# Postprocessing dataset (num_proc=2):  78% 3104/4000 [00:31<00:06, 147.42 examples/s]
# Postprocessing dataset (num_proc=2):  78% 3122/4000 [00:31<00:05, 146.82 examples/s]
# Postprocessing dataset (num_proc=2):  78% 3139/4000 [00:31<00:05, 152.37 examples/s]
# Postprocessing dataset (num_proc=2):  79% 3156/4000 [00:31<00:05, 151.37 examples/s]
# Postprocessing dataset (num_proc=2):  79% 3172/4000 [00:31<00:05, 153.01 examples/s]
# Postprocessing dataset (num_proc=2):  80% 3188/4000 [00:31<00:05, 148.89 examples/s]
# Postprocessing dataset (num_proc=2):  80% 3204/4000 [00:31<00:05, 149.20 examples/s]
# Postprocessing dataset (num_proc=2):  81% 3221/4000 [00:31<00:05, 149.84 examples/s]
# Postprocessing dataset (num_proc=2):  81% 3240/4000 [00:32<00:05, 150.12 examples/s]
# Postprocessing dataset (num_proc=2):  81% 3257/4000 [00:32<00:04, 153.37 examples/s]
# Postprocessing dataset (num_proc=2):  82% 3276/4000 [00:32<00:04, 158.39 examples/s]
# Postprocessing dataset (num_proc=2):  82% 3292/4000 [00:32<00:04, 157.50 examples/s]
# Postprocessing dataset (num_proc=2):  83% 3309/4000 [00:32<00:04, 159.26 examples/s]
# Postprocessing dataset (num_proc=2):  83% 3325/4000 [00:32<00:04, 153.07 examples/s]
# Postprocessing dataset (num_proc=2):  84% 3341/4000 [00:32<00:04, 147.79 examples/s]
# Postprocessing dataset (num_proc=2):  84% 3357/4000 [00:32<00:04, 149.38 examples/s]
# Postprocessing dataset (num_proc=2):  84% 3373/4000 [00:32<00:04, 147.34 examples/s]
# Postprocessing dataset (num_proc=2):  85% 3389/4000 [00:33<00:04, 149.42 examples/s]
# Postprocessing dataset (num_proc=2):  85% 3406/4000 [00:33<00:03, 154.08 examples/s]
# Postprocessing dataset (num_proc=2):  86% 3422/4000 [00:33<00:03, 150.38 examples/s]
# Postprocessing dataset (num_proc=2):  86% 3438/4000 [00:33<00:03, 151.46 examples/s]
# Postprocessing dataset (num_proc=2):  86% 3455/4000 [00:33<00:03, 150.98 examples/s]
# Postprocessing dataset (num_proc=2):  87% 3471/4000 [00:33<00:03, 148.81 examples/s]
# Postprocessing dataset (num_proc=2):  87% 3488/4000 [00:33<00:03, 153.33 examples/s]
# Postprocessing dataset (num_proc=2):  88% 3507/4000 [00:33<00:03, 142.90 examples/s]
# Postprocessing dataset (num_proc=2):  88% 3524/4000 [00:33<00:03, 129.24 examples/s]
# Postprocessing dataset (num_proc=2):  88% 3540/4000 [00:34<00:03, 126.15 examples/s]
# Postprocessing dataset (num_proc=2):  89% 3553/4000 [00:34<00:04, 107.89 examples/s]
# Postprocessing dataset (num_proc=2):  89% 3567/4000 [00:34<00:04, 107.20 examples/s]
# Postprocessing dataset (num_proc=2):  89% 3579/4000 [00:34<00:04, 102.44 examples/s]
# Postprocessing dataset (num_proc=2):  90% 3592/4000 [00:34<00:03, 104.83 examples/s]
# Postprocessing dataset (num_proc=2):  90% 3604/4000 [00:34<00:04, 94.70 examples/s]
# Postprocessing dataset (num_proc=2):  90% 3615/4000 [00:34<00:04, 92.68 examples/s]
# Postprocessing dataset (num_proc=2):  91% 3625/4000 [00:35<00:04, 92.50 examples/s]
# Postprocessing dataset (num_proc=2):  91% 3637/4000 [00:35<00:04, 85.95 examples/s]
# Postprocessing dataset (num_proc=2):  91% 3647/4000 [00:35<00:04, 82.95 examples/s]
# Postprocessing dataset (num_proc=2):  91% 3656/4000 [00:35<00:04, 81.91 examples/s]
# Postprocessing dataset (num_proc=2):  92% 3666/4000 [00:35<00:04, 82.27 examples/s]
# Postprocessing dataset (num_proc=2):  92% 3675/4000 [00:35<00:04, 77.61 examples/s]
# Postprocessing dataset (num_proc=2):  92% 3687/4000 [00:35<00:03, 83.66 examples/s]
# Postprocessing dataset (num_proc=2):  92% 3698/4000 [00:35<00:03, 86.38 examples/s]
# Postprocessing dataset (num_proc=2):  93% 3708/4000 [00:36<00:03, 82.29 examples/s]
# Postprocessing dataset (num_proc=2):  93% 3721/4000 [00:36<00:03, 90.41 examples/s]
# Postprocessing dataset (num_proc=2):  93% 3734/4000 [00:36<00:02, 97.47 examples/s]
# Postprocessing dataset (num_proc=2):  94% 3745/4000 [00:36<00:02, 97.02 examples/s]
# Postprocessing dataset (num_proc=2):  94% 3756/4000 [00:36<00:02, 92.70 examples/s]
# Postprocessing dataset (num_proc=2):  94% 3766/4000 [00:36<00:02, 93.78 examples/s]
# Postprocessing dataset (num_proc=2):  94% 3778/4000 [00:36<00:02, 99.37 examples/s]
# Postprocessing dataset (num_proc=2):  95% 3789/4000 [00:36<00:02, 102.02 examples/s]
# Postprocessing dataset (num_proc=2):  95% 3806/4000 [00:37<00:01, 119.55 examples/s]
# Postprocessing dataset (num_proc=2):  96% 3822/4000 [00:37<00:01, 129.75 examples/s]
# Postprocessing dataset (num_proc=2):  96% 3839/4000 [00:37<00:01, 135.28 examples/s]
# Postprocessing dataset (num_proc=2):  96% 3856/4000 [00:37<00:01, 142.67 examples/s]
# Postprocessing dataset (num_proc=2):  97% 3872/4000 [00:37<00:00, 143.76 examples/s]
# Postprocessing dataset (num_proc=2):  97% 3888/4000 [00:37<00:00, 144.89 examples/s]
# Postprocessing dataset (num_proc=2):  98% 3905/4000 [00:37<00:00, 149.57 examples/s]
# Postprocessing dataset (num_proc=2):  98% 3921/4000 [00:37<00:00, 150.93 examples/s]
# Postprocessing dataset (num_proc=2):  98% 3937/4000 [00:37<00:00, 150.50 examples/s]
# Postprocessing dataset (num_proc=2):  99% 3953/4000 [00:37<00:00, 150.63 examples/s]
# Postprocessing dataset (num_proc=2):  99% 3970/4000 [00:38<00:00, 150.45 examples/s]
# Postprocessing dataset (num_proc=2): 100% 4000/4000 [00:38<00:00, 103.98 examples/s]
#
# Saving the dataset (0/1 shards):   0% 0/4000 [00:00<?, ? examples/s]
# Saving the dataset (1/1 shards): 100% 4000/4000 [00:00<00:00, 403434.23 examples/s]
#
# Uploading the dataset shards:   0% 0/1 [00:00<?, ?it/s]
#
# Creating parquet from Arrow format: 100% 4/4 [00:00<00:00, 176.78ba/s]
#
# Uploading the dataset shards: 100% 1/1 [00:01<00:00,  1.06s/it]
#
# README.md: 100% 884/884 [00:00<00:00, 3.83MB/s]
#  ... : 100% 334/334 [00:51<00:00,  6.49it/s]

# %% [markdown]
# Let's take a look at some created prompts:

# %%
from datasets import load_dataset
dataset = load_dataset("ylacombe/jenny-tts-6h-tagged")
print("1st sample:", dataset["train"][0]["text_description"])
print("2nd sample:", dataset["train"][1]["text_description"])
del dataset
# Out:
# 1st sample: 'The speech sample is very noisy, contains a lot of background noise, and is delivered in a monotone tone with occasional fast bursts.'
# 2nd sample: 'Jenny's speech is very noisy, but she speaks in a very monotone voice with minimal variation in speed.'.

# %% [markdown]
# **Observation:** The first sample unfortunately doesn't have the name Jenny in it. This is probably because we use a smaller and thus less precise model that one we would have gone for if this notebook had more resources (e.g we've used [Mistral 7B v2](https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.2) to create the Parler-TTS training dataset). This shouldn't prevent our model to learn what we want though.

# %% [markdown]
# ## Fine-tuning Parler-TTS

# %%
# %cd ../parler-tts
# Out:
# /content/parler-tts

# %% [markdown]
# We can know fully focus on fine-tuning Parler-TTS. Luckily, [the Parler-TTS library](https://github.com/huggingface/.parler-tts) has a training script available [here](https://github.com/huggingface/parler-tts/tree/main/training), that can be used with just a few arguments.
#
#
# > **Note:** you need to enter your choice concerning WandB. If you don't have an account, you can enter `3` to avoid logging on WandB. Otherwise; you can logging to follow how your model trained.

# %%
# !accelerate launch ./training/run_parler_tts_training.py \
    --model_name_or_path "parler-tts/parler_tts_mini_v0.1" \
    --feature_extractor_name "parler-tts/dac_44khZ_8kbps" \
    --description_tokenizer_name "parler-tts/parler_tts_mini_v0.1" \
    --prompt_tokenizer_name "parler-tts/parler_tts_mini_v0.1" \
    --report_to "wandb" \
    --overwrite_output_dir true \
    --train_dataset_name "ylacombe/jenny-tts-6h" \
    --train_metadata_dataset_name "ylacombe/jenny-tts-6h-tagged" \
    --train_dataset_config_name "default" \
    --train_split_name "train" \
    --eval_dataset_name "ylacombe/jenny-tts-6h" \
    --eval_metadata_dataset_name "ylacombe/jenny-tts-6h-tagged" \
    --eval_dataset_config_name "default" \
    --eval_split_name "train" \
    --max_eval_samples 8 \
    --per_device_eval_batch_size 8 \
    --target_audio_column_name "audio" \
    --description_column_name "text_description" \
    --prompt_column_name "text" \
    --max_duration_in_seconds 20 \
    --min_duration_in_seconds 2.0 \
    --max_text_length 400 \
    --preprocessing_num_workers 2 \
    --do_train true \
    --num_train_epochs 2 \
    --gradient_accumulation_steps 18 \
    --gradient_checkpointing true \
    --per_device_train_batch_size 2 \
    --learning_rate 0.00008 \
    --adam_beta1 0.9 \
    --adam_beta2 0.99 \
    --weight_decay 0.01 \
    --lr_scheduler_type "constant_with_warmup" \
    --warmup_steps 50 \
    --logging_steps 2 \
    --freeze_text_encoder true \
    --audio_encoder_per_device_batch_size 4 \
    --dtype "float16" \
    --seed 456 \
    --output_dir "./output_dir_training/" \
    --temporary_save_to_disk "./audio_code_tmp/" \
    --save_to_disk "./tmp_dataset_audio/" \
    --dataloader_num_workers 2 \
    --do_eval \
    --predict_with_generate \
    --include_inputs_for_metrics \
    --group_by_length true
# Out:
# The following values were not passed to `accelerate launch` and had defaults used instead:
# 	`--num_processes` was set to a value of `1`
# 	`--num_machines` was set to a value of `1`
# 	`--mixed_precision` was set to a value of `'no'`
# 	`--dynamo_backend` was set to a value of `'no'`
# To avoid this warning pass in values for each of the problematic parameters or run `accelerate config`.
# 2024-04-30 14:53:59.378318: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-30 14:53:59.378373: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-30 14:53:59.379895: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-30 14:54:00.583065: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 3
# wandb: You chose "Don't visualize my results"
# wandb: Tracking run with wandb version 0.16.6
# wandb: W&B syncing is set to `offline` in this directory.
# wandb: Run `wandb online` or set WANDB_MODE=online to enable cloud syncing.
# 04/30/2024 14:54:17 - WARNING - __main__ - Process rank: 0, device: cuda:0, n_gpu: 1, distributed training: False, 16-bits training: False
# 04/30/2024 14:54:17 - INFO - __main__ - Training/evaluation parameters ParlerTTSTrainingArguments(
# _n_gpu=1,
# accelerator_config={'split_batches': False, 'dispatch_batches': None, 'even_batches': True, 'use_seedable_sampler': True, 'gradient_accumulation_kwargs': None},
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.99,
# adam_epsilon=1e-08,
# audio_encoder_per_device_batch_size=4,
# auto_find_batch_size=False,
# bf16=False,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=2,
# dataloader_persistent_workers=False,
# dataloader_pin_memory=True,
# dataloader_prefetch_factor=None,
# ddp_backend=None,
# ddp_broadcast_buffers=None,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# ddp_timeout=1800,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# dispatch_batches=None,
# do_eval=True,
# do_predict=False,
# do_train=True,
# dtype=float16,
# eval_accumulation_steps=None,
# eval_delay=0,
# eval_do_concat_batches=True,
# eval_steps=None,
# evaluation_strategy=no,
# fp16=False,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# fsdp=[],
# fsdp_config={'min_num_params': 0, 'xla': False, 'xla_fsdp_v2': False, 'xla_fsdp_grad_ckpt': False},
# fsdp_min_num_params=0,
# fsdp_transformer_layer_cls_to_wrap=None,
# full_determinism=False,
# generation_config=None,
# generation_max_length=None,
# generation_num_beams=None,
# gradient_accumulation_steps=18,
# gradient_checkpointing=True,
# gradient_checkpointing_kwargs=None,
# greater_is_better=None,
# group_by_length=True,
# half_precision_backend=auto,
# hub_always_push=False,
# hub_model_id=None,
# hub_private_repo=False,
# hub_strategy=every_save,
# hub_token=<HUB_TOKEN>,
# ignore_data_skip=False,
# include_inputs_for_metrics=True,
# include_num_input_tokens_seen=False,
# include_tokens_per_second=False,
# jit_mode_eval=False,
# label_names=None,
# label_smoothing_factor=0.0,
# learning_rate=8e-05,
# length_column_name=length,
# load_best_model_at_end=False,
# local_rank=0,
# log_level=passive,
# log_level_replica=warning,
# log_on_each_node=True,
# logging_dir=./output_dir_training/runs/Apr30_14-54-03_9d2610d910c5,
# logging_first_step=False,
# logging_nan_inf_filter=True,
# logging_steps=2,
# logging_strategy=steps,
# lr_scheduler_kwargs={},
# lr_scheduler_type=constant_with_warmup,
# max_grad_norm=1.0,
# max_steps=-1,
# metric_for_best_model=None,
# mp_parameters=,
# neftune_noise_alpha=None,
# no_cuda=False,
# num_train_epochs=2.0,
# optim=adamw_torch,
# optim_args=None,
# optim_target_modules=None,
# output_dir=./output_dir_training/,
# overwrite_output_dir=True,
# past_index=-1,
# per_device_eval_batch_size=8,
# per_device_train_batch_size=2,
# predict_with_generate=True,
# prediction_loss_only=False,
# push_to_hub=False,
# push_to_hub_model_id=None,
# push_to_hub_organization=None,
# push_to_hub_token=<PUSH_TO_HUB_TOKEN>,
# ray_scope=last,
# remove_unused_columns=True,
# report_to=['wandb'],
# resume_from_checkpoint=None,
# run_name=./output_dir_training/,
# save_on_each_node=False,
# save_only_model=False,
# save_safetensors=True,
# save_steps=500,
# save_strategy=steps,
# save_total_limit=None,
# seed=456,
# skip_memory_metrics=True,
# sortish_sampler=False,
# split_batches=None,
# tf32=None,
# torch_compile=False,
# torch_compile_backend=None,
# torch_compile_mode=None,
# torchdynamo=None,
# tpu_metrics_debug=False,
# tpu_num_cores=None,
# use_cpu=False,
# use_ipex=False,
# use_legacy_prediction_loop=False,
# use_mps_device=False,
# warmup_ratio=0.0,
# warmup_steps=50,
# weight_decay=0.01,
# )
# loading configuration file preprocessor_config.json from cache at /root/.cache/huggingface/hub/models--parler-tts--dac_44khZ_8kbps/snapshots/db52bea859d9411e0beb44a3ea923a8731ee4197/preprocessor_config.json
# Feature extractor EncodecFeatureExtractor {
#   "chunk_length_s": null,
#   "feature_extractor_type": "EncodecFeatureExtractor",
#   "feature_size": 1,
#   "overlap": null,
#   "padding_side": "right",
#   "padding_value": 0.0,
#   "return_attention_mask": true,
#   "sampling_rate": 44100
# }
#
# loading file spiece.model from cache at /root/.cache/huggingface/hub/models--parler-tts--parler_tts_mini_v0.1/snapshots/52fee740c2207e8bd6d2b974330fc0411aa31367/spiece.model
# loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--parler-tts--parler_tts_mini_v0.1/snapshots/52fee740c2207e8bd6d2b974330fc0411aa31367/tokenizer.json
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at /root/.cache/huggingface/hub/models--parler-tts--parler_tts_mini_v0.1/snapshots/52fee740c2207e8bd6d2b974330fc0411aa31367/special_tokens_map.json
# loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--parler-tts--parler_tts_mini_v0.1/snapshots/52fee740c2207e8bd6d2b974330fc0411aa31367/tokenizer_config.json
# You set `add_prefix_space`. The tokenizer needs to be converted from the slow tokenizers
# loading file spiece.model from cache at /root/.cache/huggingface/hub/models--parler-tts--parler_tts_mini_v0.1/snapshots/52fee740c2207e8bd6d2b974330fc0411aa31367/spiece.model
# loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--parler-tts--parler_tts_mini_v0.1/snapshots/52fee740c2207e8bd6d2b974330fc0411aa31367/tokenizer.json
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at /root/.cache/huggingface/hub/models--parler-tts--parler_tts_mini_v0.1/snapshots/52fee740c2207e8bd6d2b974330fc0411aa31367/special_tokens_map.json
# loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--parler-tts--parler_tts_mini_v0.1/snapshots/52fee740c2207e8bd6d2b974330fc0411aa31367/tokenizer_config.json
# 04/30/2024 14:54:18 - WARNING - __main__ - Disabling fast tokenizer warning: https://github.com/huggingface/transformers/blob/main/src/transformers/tokenization_utils_base.py#L3231-L3235
# Combining datasets...:   0% 0/1 [00:00<?, ?it/s]04/30/2024 14:54:20 - INFO - __main__ - Merging ylacombe/jenny-tts-6h - train with ylacombe/jenny-tts-6h-tagged - train
# Combining datasets...: 100% 1/1 [00:03<00:00,  3.65s/it]
# Combining datasets...:   0% 0/1 [00:00<?, ?it/s]04/30/2024 14:54:22 - INFO - __main__ - Merging ylacombe/jenny-tts-6h - train with ylacombe/jenny-tts-6h-tagged - train
# Combining datasets...: 100% 1/1 [00:02<00:00,  2.70s/it]
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--parler-tts--parler_tts_mini_v0.1/snapshots/52fee740c2207e8bd6d2b974330fc0411aa31367/config.json
# Model config ParlerTTSConfig {
#   "_name_or_path": "/fsx/yoach/tmp/artefacts/training-400M-punctuated-v2/",
#   "architectures": [
#     "ParlerTTSForConditionalGeneration"
#   ],
#   "audio_encoder": {
#     "_name_or_path": "ylacombe/dac_44khZ_8kbps",
#     "add_cross_attention": false,
#     "architectures": [
#       "DACModel"
#     ],
#     "bad_words_ids": null,
#     "begin_suppress_tokens": null,
#     "bos_token_id": null,
#     "chunk_size_feed_forward": 0,
#     "codebook_size": 1024,
#     "cross_attention_hidden_size": null,
#     "decoder_start_token_id": null,
#     "diversity_penalty": 0.0,
#     "do_sample": false,
#     "early_stopping": false,
#     "encoder_no_repeat_ngram_size": 0,
#     "eos_token_id": null,
#     "exponential_decay_length_penalty": null,
#     "finetuning_task": null,
#     "forced_bos_token_id": null,
#     "forced_eos_token_id": null,
#     "frame_rate": 86,
#     "id2label": {
#       "0": "LABEL_0",
#       "1": "LABEL_1"
#     },
#     "is_decoder": false,
#     "is_encoder_decoder": false,
#     "label2id": {
#       "LABEL_0": 0,
#       "LABEL_1": 1
#     },
#     "latent_dim": 1024,
#     "length_penalty": 1.0,
#     "max_length": 20,
#     "min_length": 0,
#     "model_bitrate": 8,
#     "model_type": "dac",
#     "no_repeat_ngram_size": 0,
#     "num_beam_groups": 1,
#     "num_beams": 1,
#     "num_codebooks": 9,
#     "num_return_sequences": 1,
#     "output_attentions": false,
#     "output_hidden_states": false,
#     "output_scores": false,
#     "pad_token_id": null,
#     "prefix": null,
#     "problem_type": null,
#     "pruned_heads": {},
#     "remove_invalid_values": false,
#     "repetition_penalty": 1.0,
#     "return_dict": true,
#     "return_dict_in_generate": false,
#     "sampling_rate": 44100,
#     "sep_token_id": null,
#     "suppress_tokens": null,
#     "task_specific_params": null,
#     "temperature": 1.0,
#     "tf_legacy_loss": false,
#     "tie_encoder_decoder": false,
#     "tie_word_embeddings": true,
#     "tokenizer_class": null,
#     "top_k": 50,
#     "top_p": 1.0,
#     "torch_dtype": "float32",
#     "torchscript": false,
#     "typical_p": 1.0,
#     "use_bfloat16": false
#   },
#   "decoder": {
#     "_name_or_path": "/fsx/yoach/tmp/artefacts/decoder_400M/",
#     "activation_dropout": 0.0,
#     "activation_function": "gelu",
#     "add_cross_attention": true,
#     "architectures": [
#       "ParlerTTSForCausalLM"
#     ],
#     "attention_dropout": 0.0,
#     "bad_words_ids": null,
#     "begin_suppress_tokens": null,
#     "bos_token_id": 1025,
#     "chunk_size_feed_forward": 0,
#     "cross_attention_hidden_size": null,
#     "decoder_start_token_id": null,
#     "diversity_penalty": 0.0,
#     "do_sample": false,
#     "dropout": 0.1,
#     "early_stopping": false,
#     "encoder_no_repeat_ngram_size": 0,
#     "eos_token_id": 1024,
#     "exponential_decay_length_penalty": null,
#     "ffn_dim": 4096,
#     "finetuning_task": null,
#     "forced_bos_token_id": null,
#     "forced_eos_token_id": null,
#     "hidden_size": 1024,
#     "id2label": {
#       "0": "LABEL_0",
#       "1": "LABEL_1"
#     },
#     "initializer_factor": 0.02,
#     "is_decoder": true,
#     "is_encoder_decoder": false,
#     "label2id": {
#       "LABEL_0": 0,
#       "LABEL_1": 1
#     },
#     "layerdrop": 0.0,
#     "length_penalty": 1.0,
#     "max_length": 20,
#     "max_position_embeddings": 4096,
#     "min_length": 0,
#     "model_type": "parler_tts_decoder",
#     "no_repeat_ngram_size": 0,
#     "num_attention_heads": 16,
#     "num_beam_groups": 1,
#     "num_beams": 1,
#     "num_codebooks": 9,
#     "num_hidden_layers": 24,
#     "num_return_sequences": 1,
#     "output_attentions": false,
#     "output_hidden_states": false,
#     "output_scores": false,
#     "pad_token_id": 1024,
#     "prefix": null,
#     "problem_type": null,
#     "pruned_heads": {},
#     "remove_invalid_values": false,
#     "repetition_penalty": 1.0,
#     "return_dict": true,
#     "return_dict_in_generate": false,
#     "scale_embedding": false,
#     "sep_token_id": null,
#     "suppress_tokens": null,
#     "task_specific_params": null,
#     "temperature": 1.0,
#     "tf_legacy_loss": false,
#     "tie_encoder_decoder": false,
#     "tie_word_embeddings": false,
#     "tokenizer_class": null,
#     "top_k": 50,
#     "top_p": 1.0,
#     "torch_dtype": "float32",
#     "torchscript": false,
#     "typical_p": 1.0,
#     "use_bfloat16": false,
#     "use_cache": true,
#     "vocab_size": 1088
#   },
#   "decoder_start_token_id": 1025,
#   "is_encoder_decoder": true,
#   "model_type": "parler_tts",
#   "pad_token_id": 1024,
#   "text_encoder": {
#     "_name_or_path": "google/flan-t5-base",
#     "add_cross_attention": false,
#     "architectures": [
#       "T5ForConditionalGeneration"
#     ],
#     "bad_words_ids": null,
#     "begin_suppress_tokens": null,
#     "bos_token_id": null,
#     "chunk_size_feed_forward": 0,
#     "classifier_dropout": 0.0,
#     "cross_attention_hidden_size": null,
#     "d_ff": 2048,
#     "d_kv": 64,
#     "d_model": 768,
#     "decoder_start_token_id": 0,
#     "dense_act_fn": "gelu_new",
#     "diversity_penalty": 0.0,
#     "do_sample": false,
#     "dropout_rate": 0.1,
#     "early_stopping": false,
#     "encoder_no_repeat_ngram_size": 0,
#     "eos_token_id": 1,
#     "exponential_decay_length_penalty": null,
#     "feed_forward_proj": "gated-gelu",
#     "finetuning_task": null,
#     "forced_bos_token_id": null,
#     "forced_eos_token_id": null,
#     "id2label": {
#       "0": "LABEL_0",
#       "1": "LABEL_1"
#     },
#     "initializer_factor": 1.0,
#     "is_decoder": false,
#     "is_encoder_decoder": true,
#     "is_gated_act": true,
#     "label2id": {
#       "LABEL_0": 0,
#       "LABEL_1": 1
#     },
#     "layer_norm_epsilon": 1e-06,
#     "length_penalty": 1.0,
#     "max_length": 20,
#     "min_length": 0,
#     "model_type": "t5",
#     "n_positions": 512,
#     "no_repeat_ngram_size": 0,
#     "num_beam_groups": 1,
#     "num_beams": 1,
#     "num_decoder_layers": 12,
#     "num_heads": 12,
#     "num_layers": 12,
#     "num_return_sequences": 1,
#     "output_attentions": false,
#     "output_hidden_states": false,
#     "output_past": true,
#     "output_scores": false,
#     "pad_token_id": 0,
#     "prefix": null,
#     "problem_type": null,
#     "pruned_heads": {},
#     "relative_attention_max_distance": 128,
#     "relative_attention_num_buckets": 32,
#     "remove_invalid_values": false,
#     "repetition_penalty": 1.0,
#     "return_dict": true,
#     "return_dict_in_generate": false,
#     "sep_token_id": null,
#     "suppress_tokens": null,
#     "task_specific_params": {
#       "summarization": {
#         "early_stopping": true,
#         "length_penalty": 2.0,
#         "max_length": 200,
#         "min_length": 30,
#         "no_repeat_ngram_size": 3,
#         "num_beams": 4,
#         "prefix": "summarize: "
#       },
#       "translation_en_to_de": {
#         "early_stopping": true,
#         "max_length": 300,
#         "num_beams": 4,
#         "prefix": "translate English to German: "
#       },
#       "translation_en_to_fr": {
#         "early_stopping": true,
#         "max_length": 300,
#         "num_beams": 4,
#         "prefix": "translate English to French: "
#       },
#       "translation_en_to_ro": {
#         "early_stopping": true,
#         "max_length": 300,
#         "num_beams": 4,
#         "prefix": "translate English to Romanian: "
#       }
#     },
#     "temperature": 1.0,
#     "tf_legacy_loss": false,
#     "tie_encoder_decoder": false,
#     "tie_word_embeddings": false,
#     "tokenizer_class": null,
#     "top_k": 50,
#     "top_p": 1.0,
#     "torch_dtype": null,
#     "torchscript": false,
#     "typical_p": 1.0,
#     "use_bfloat16": false,
#     "use_cache": true,
#     "vocab_size": 32128
#   },
#   "torch_dtype": "float32",
#   "transformers_version": "4.40.0",
#   "vocab_size": 32128
# }
#
# loading weights file model.safetensors from cache at /root/.cache/huggingface/hub/models--parler-tts--parler_tts_mini_v0.1/snapshots/52fee740c2207e8bd6d2b974330fc0411aa31367/model.safetensors
# Generate config GenerationConfig {
#   "decoder_start_token_id": 1025,
#   "pad_token_id": 1024
# }
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/utils/weight_norm.py:28: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# Generate config GenerationConfig {
#   "bos_token_id": 1025,
#   "eos_token_id": 1024,
#   "pad_token_id": 1024
# }
#
# All model checkpoint weights were used when initializing ParlerTTSForConditionalGeneration.
#
# All the weights of ParlerTTSForConditionalGeneration were initialized from the model checkpoint at parler-tts/parler_tts_mini_v0.1.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use ParlerTTSForConditionalGeneration for predictions without further training.
# loading configuration file generation_config.json from cache at /root/.cache/huggingface/hub/models--parler-tts--parler_tts_mini_v0.1/snapshots/52fee740c2207e8bd6d2b974330fc0411aa31367/generation_config.json
# Generate config GenerationConfig {
#   "bos_token_id": 1025,
#   "decoder_start_token_id": 1025,
#   "do_sample": true,
#   "eos_token_id": 1024,
#   "guidance_scale": 1.0,
#   "max_length": 2580,
#   "min_new_tokens": 50,
#   "pad_token_id": 1024
# }
#
# gathered_tensor tensor([0], device='cuda:0')
# Filter (num_proc=2):   0% 0/4000 [00:00<?, ? examples/s]2024-04-30 14:54:50.348634: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-30 14:54:50.348696: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-30 14:54:50.350497: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-30 14:54:50.395053: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-30 14:54:50.395099: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-30 14:54:50.396980: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-30 14:54:50.500233: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-30 14:54:50.500289: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-30 14:54:50.502112: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-30 14:54:53.169062: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-04-30 14:54:53.448198: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-04-30 14:54:53.717173: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Filter (num_proc=2): 100% 4000/4000 [00:21<00:00, 188.75 examples/s]
# Filter (num_proc=2):   0% 0/8 [00:00<?, ? examples/s]2024-04-30 14:55:12.201660: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-30 14:55:12.201714: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-30 14:55:12.204676: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-30 14:55:12.204723: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-30 14:55:12.205166: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-30 14:55:12.205205: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-30 14:55:12.206340: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-30 14:55:12.206629: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-30 14:55:12.210376: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-30 14:55:15.146701: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-04-30 14:55:15.222662: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-04-30 14:55:15.294126: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Filter (num_proc=2): 100% 8/8 [00:21<00:00,  2.65s/ examples]
# preprocess datasets (num_proc=2):   0% 0/4000 [00:00<?, ? examples/s]2024-04-30 14:55:31.758055: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-30 14:55:31.758109: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-30 14:55:31.759968: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-30 14:55:31.836199: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-30 14:55:31.836257: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-30 14:55:31.837945: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-30 14:55:32.520096: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-30 14:55:32.520153: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-30 14:55:32.521840: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-30 14:55:34.474005: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-04-30 14:55:35.672629: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-04-30 14:55:36.197772: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# preprocess datasets (num_proc=2): 100% 4000/4000 [00:21<00:00, 188.50 examples/s]
# preprocess datasets (num_proc=2):   0% 0/8 [00:00<?, ? examples/s]2024-04-30 14:55:54.670486: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-30 14:55:54.670563: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-30 14:55:54.672404: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-30 14:55:54.866873: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-30 14:55:54.866933: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-30 14:55:54.868603: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-30 14:55:55.037194: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-30 14:55:55.037250: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-30 14:55:55.038824: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-30 14:55:57.253484: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-04-30 14:55:58.045630: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-04-30 14:55:58.213588: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# preprocess datasets (num_proc=2): 100% 8/8 [00:21<00:00,  2.67s/ examples]
# 04/30/2024 14:56:08 - INFO - __main__ - *** Encode target audio with encodec ***
#   0% 0/1000 [00:00<?, ?it/s]/usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
# It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
# It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
# It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
# It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
# It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   0% 1/1000 [00:05<1:31:55,  5.52s/it]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   0% 2/1000 [00:06<43:56,  2.64s/it]  It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   0% 3/1000 [00:06<29:23,  1.77s/it]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   0% 4/1000 [00:07<23:41,  1.43s/it]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   0% 5/1000 [00:08<19:58,  1.20s/it]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   1% 6/1000 [00:09<18:20,  1.11s/it]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   1% 7/1000 [00:10<15:29,  1.07it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   1% 8/1000 [00:10<13:38,  1.21it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   1% 9/1000 [00:11<11:17,  1.46it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   1% 10/1000 [00:11<11:10,  1.48it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   1% 11/1000 [00:12<09:57,  1.65it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   1% 12/1000 [00:12<09:22,  1.76it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   1% 13/1000 [00:13<08:41,  1.89it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   1% 14/1000 [00:13<09:49,  1.67it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   2% 15/1000 [00:14<11:22,  1.44it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   2% 16/1000 [00:15<11:24,  1.44it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   2% 17/1000 [00:16<11:15,  1.45it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   2% 18/1000 [00:16<08:39,  1.89it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   2% 19/1000 [00:16<08:09,  2.00it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   2% 20/1000 [00:17<08:18,  1.97it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   2% 21/1000 [00:17<08:00,  2.04it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   2% 22/1000 [00:18<08:57,  1.82it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   2% 23/1000 [00:18<07:52,  2.07it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   2% 24/1000 [00:19<08:18,  1.96it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   2% 25/1000 [00:20<09:42,  1.67it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   3% 26/1000 [00:20<09:30,  1.71it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   3% 27/1000 [00:21<10:41,  1.52it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   3% 28/1000 [00:22<11:02,  1.47it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   3% 29/1000 [00:23<12:25,  1.30it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   3% 30/1000 [00:23<11:36,  1.39it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   3% 31/1000 [00:24<11:39,  1.39it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   3% 32/1000 [00:25<11:46,  1.37it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   3% 33/1000 [00:26<13:00,  1.24it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   3% 34/1000 [00:26<11:40,  1.38it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   4% 35/1000 [00:27<11:46,  1.37it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   4% 36/1000 [00:28<11:17,  1.42it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   4% 37/1000 [00:28<09:37,  1.67it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   4% 38/1000 [00:29<10:55,  1.47it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   4% 39/1000 [00:30<13:51,  1.16it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   4% 40/1000 [00:31<12:49,  1.25it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   4% 41/1000 [00:31<11:12,  1.43it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   4% 42/1000 [00:32<10:23,  1.54it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   4% 43/1000 [00:32<10:11,  1.57it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   4% 44/1000 [00:33<08:32,  1.87it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   4% 45/1000 [00:33<07:47,  2.04it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   5% 46/1000 [00:33<06:59,  2.27it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   5% 47/1000 [00:34<06:30,  2.44it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   5% 48/1000 [00:34<07:20,  2.16it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   5% 49/1000 [00:35<08:57,  1.77it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   5% 50/1000 [00:36<08:43,  1.82it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   5% 51/1000 [00:37<10:29,  1.51it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   5% 52/1000 [00:38<12:02,  1.31it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   5% 53/1000 [00:38<12:31,  1.26it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   5% 54/1000 [00:39<12:41,  1.24it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   6% 55/1000 [00:40<11:20,  1.39it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   6% 56/1000 [00:40<10:40,  1.47it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   6% 57/1000 [00:41<10:41,  1.47it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   6% 58/1000 [00:42<10:19,  1.52it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   6% 59/1000 [00:42<09:05,  1.72it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   6% 60/1000 [00:43<08:53,  1.76it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   6% 61/1000 [00:43<07:58,  1.96it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   6% 62/1000 [00:44<09:25,  1.66it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   6% 63/1000 [00:44<09:32,  1.64it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   6% 64/1000 [00:45<10:01,  1.56it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   6% 65/1000 [00:46<10:21,  1.51it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   7% 66/1000 [00:47<10:12,  1.52it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   7% 67/1000 [00:47<10:54,  1.42it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   7% 68/1000 [00:48<12:24,  1.25it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   7% 69/1000 [00:49<11:43,  1.32it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   7% 70/1000 [00:50<11:21,  1.37it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   7% 71/1000 [00:51<12:06,  1.28it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   7% 72/1000 [00:51<11:41,  1.32it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   7% 73/1000 [00:52<12:09,  1.27it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   7% 74/1000 [00:53<12:52,  1.20it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   8% 75/1000 [00:54<12:59,  1.19it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   8% 76/1000 [00:55<12:24,  1.24it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   8% 77/1000 [00:55<11:35,  1.33it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   8% 78/1000 [00:56<11:03,  1.39it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   8% 79/1000 [00:57<11:24,  1.35it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   8% 80/1000 [00:57<10:20,  1.48it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   8% 81/1000 [00:58<09:33,  1.60it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   8% 82/1000 [00:59<11:15,  1.36it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   8% 83/1000 [01:00<11:56,  1.28it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   8% 84/1000 [01:00<11:31,  1.32it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   8% 85/1000 [01:01<11:12,  1.36it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   9% 86/1000 [01:02<11:00,  1.38it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   9% 87/1000 [01:02<10:45,  1.42it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   9% 88/1000 [01:03<09:44,  1.56it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   9% 89/1000 [01:04<11:49,  1.28it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   9% 90/1000 [01:05<12:54,  1.17it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   9% 91/1000 [01:06<12:27,  1.22it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   9% 92/1000 [01:06<11:46,  1.29it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   9% 93/1000 [01:07<12:48,  1.18it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#   9% 94/1000 [01:09<14:50,  1.02it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#  10% 95/1000 [01:09<13:24,  1.12it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#  10% 96/1000 [01:10<11:09,  1.35it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#  10% 97/1000 [01:11<10:57,  1.37it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#  10% 98/1000 [01:11<09:56,  1.51it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#  10% 99/1000 [01:12<10:34,  1.42it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#  10% 100/1000 [01:13<10:56,  1.37it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#  10% 101/1000 [01:13<10:19,  1.45it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#  10% 102/1000 [01:14<08:35,  1.74it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
#  10% 103/1000 [01:14<09:47,  1.53it/s]It is strongly recommended to pass the `sampling_rate` argument to this function. Failing to do so can result in silent errors that might be hard to debug.
# ...
#   "encoder_layerdrop": 0.0,
#   "encoder_layers": 32,
#   "eos_token_id": 50257,
#   "forced_decoder_ids": [
#     [
#       1,
#       50259
#     ],
#     [
#       2,
#       50359
#     ],
#     [
#       3,
#       50363
#     ]
#   ],
#   "init_std": 0.02,
#   "is_encoder_decoder": true,
#   "mask_feature_length": 10,
#   "mask_feature_min_masks": 0,
#   "mask_feature_prob": 0.0,
#   "mask_time_length": 10,
#   "mask_time_min_masks": 2,
#   "mask_time_prob": 0.05,
#   "max_length": 448,
#   "max_source_positions": 1500,
#   "max_target_positions": 448,
#   "median_filter_width": 7,
#   "model_type": "whisper",
#   "num_hidden_layers": 32,
#   "num_mel_bins": 80,
#   "pad_token_id": 50257,
#   "scale_embedding": false,
#   "suppress_tokens": [
#     1,
#     2,
#     7,
#     8,
#     9,
#     10,
#     14,
#     25,
#     26,
#     27,
#     28,
#     29,
#     31,
#     58,
#     59,
#     60,
#     61,
#     62,
#     63,
#     90,
#     91,
#     92,
#     93,
#     359,
#     503,
#     522,
#     542,
#     873,
#     893,
#     902,
#     918,
#     922,
#     931,
#     1350,
#     1853,
#     1982,
#     2460,
#     2627,
#     3246,
#     3253,
#     3268,
#     3536,
#     3846,
#     3961,
#     4183,
#     4667,
#     6585,
#     6647,
#     7273,
#     9061,
#     9383,
#     10428,
#     10929,
#     11938,
#     12033,
#     12331,
#     12562,
#     13793,
#     14157,
#     14635,
#     15265,
#     15618,
#     16553,
#     16604,
#     18362,
#     18956,
#     20075,
#     21675,
#     22520,
#     26130,
#     26161,
#     26435,
#     28279,
#     29464,
#     31650,
#     32302,
#     32470,
#     36865,
#     42863,
#     47425,
#     49870,
#     50254,
#     50258,
#     50360,
#     50361,
#     50362
#   ],
#   "torch_dtype": "float32",
#   "transformers_version": "4.40.0",
#   "use_cache": true,
#   "use_weighted_layer_sum": false,
#   "vocab_size": 51865
# }
#
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--distil-whisper--distil-large-v2/snapshots/66bb165856c86b9eae9dba7830c0cd7d859f4ef4/config.json
# Model config WhisperConfig {
#   "_name_or_path": "distil-whisper/distil-large-v2",
#   "activation_dropout": 0.0,
#   "activation_function": "gelu",
#   "apply_spec_augment": false,
#   "architectures": [
#     "WhisperForConditionalGeneration"
#   ],
#   "attention_dropout": 0.0,
#   "begin_suppress_tokens": [
#     220,
#     50257
#   ],
#   "bos_token_id": 50257,
#   "classifier_proj_size": 256,
#   "d_model": 1280,
#   "decoder_attention_heads": 20,
#   "decoder_ffn_dim": 5120,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 2,
#   "decoder_start_token_id": 50258,
#   "dropout": 0.0,
#   "encoder_attention_heads": 20,
#   "encoder_ffn_dim": 5120,
#   "encoder_layerdrop": 0.0,
#   "encoder_layers": 32,
#   "eos_token_id": 50257,
#   "forced_decoder_ids": [
#     [
#       1,
#       50259
#     ],
#     [
#       2,
#       50359
#     ],
#     [
#       3,
#       50363
#     ]
#   ],
#   "init_std": 0.02,
#   "is_encoder_decoder": true,
#   "mask_feature_length": 10,
#   "mask_feature_min_masks": 0,
#   "mask_feature_prob": 0.0,
#   "mask_time_length": 10,
#   "mask_time_min_masks": 2,
#   "mask_time_prob": 0.05,
#   "max_length": 448,
#   "max_source_positions": 1500,
#   "max_target_positions": 448,
#   "median_filter_width": 7,
#   "model_type": "whisper",
#   "num_hidden_layers": 32,
#   "num_mel_bins": 80,
#   "pad_token_id": 50257,
#   "scale_embedding": false,
#   "suppress_tokens": [
#     1,
#     2,
#     7,
#     8,
#     9,
#     10,
#     14,
#     25,
#     26,
#     27,
#     28,
#     29,
#     31,
#     58,
#     59,
#     60,
#     61,
#     62,
#     63,
#     90,
#     91,
#     92,
#     93,
#     359,
#     503,
#     522,
#     542,
#     873,
#     893,
#     902,
#     918,
#     922,
#     931,
#     1350,
#     1853,
#     1982,
#     2460,
#     2627,
#     3246,
#     3253,
#     3268,
#     3536,
#     3846,
#     3961,
#     4183,
#     4667,
#     6585,
#     6647,
#     7273,
#     9061,
#     9383,
#     10428,
#     10929,
#     11938,
#     12033,
#     12331,
#     12562,
#     13793,
#     14157,
#     14635,
#     15265,
#     15618,
#     16553,
#     16604,
#     18362,
#     18956,
#     20075,
#     21675,
#     22520,
#     26130,
#     26161,
#     26435,
#     28279,
#     29464,
#     31650,
#     32302,
#     32470,
#     36865,
#     42863,
#     47425,
#     49870,
#     50254,
#     50258,
#     50360,
#     50361,
#     50362
#   ],
#   "torch_dtype": "float32",
#   "transformers_version": "4.40.0",
#   "use_cache": true,
#   "use_weighted_layer_sum": false,
#   "vocab_size": 51865
# }
#
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--distil-whisper--distil-large-v2/snapshots/66bb165856c86b9eae9dba7830c0cd7d859f4ef4/config.json
# Model config WhisperConfig {
#   "_name_or_path": "distil-whisper/distil-large-v2",
#   "activation_dropout": 0.0,
#   "activation_function": "gelu",
#   "apply_spec_augment": false,
#   "architectures": [
#     "WhisperForConditionalGeneration"
#   ],
#   "attention_dropout": 0.0,
#   "begin_suppress_tokens": [
#     220,
#     50257
#   ],
#   "bos_token_id": 50257,
#   "classifier_proj_size": 256,
#   "d_model": 1280,
#   "decoder_attention_heads": 20,
#   "decoder_ffn_dim": 5120,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 2,
#   "decoder_start_token_id": 50258,
#   "dropout": 0.0,
#   "encoder_attention_heads": 20,
#   "encoder_ffn_dim": 5120,
#   "encoder_layerdrop": 0.0,
#   "encoder_layers": 32,
#   "eos_token_id": 50257,
#   "forced_decoder_ids": [
#     [
#       1,
#       50259
#     ],
#     [
#       2,
#       50359
#     ],
#     [
#       3,
#       50363
#     ]
#   ],
#   "init_std": 0.02,
#   "is_encoder_decoder": true,
#   "mask_feature_length": 10,
#   "mask_feature_min_masks": 0,
#   "mask_feature_prob": 0.0,
#   "mask_time_length": 10,
#   "mask_time_min_masks": 2,
#   "mask_time_prob": 0.05,
#   "max_length": 448,
#   "max_source_positions": 1500,
#   "max_target_positions": 448,
#   "median_filter_width": 7,
#   "model_type": "whisper",
#   "num_hidden_layers": 32,
#   "num_mel_bins": 80,
#   "pad_token_id": 50257,
#   "scale_embedding": false,
#   "suppress_tokens": [
#     1,
#     2,
#     7,
#     8,
#     9,
#     10,
#     14,
#     25,
#     26,
#     27,
#     28,
#     29,
#     31,
#     58,
#     59,
#     60,
#     61,
#     62,
#     63,
#     90,
#     91,
#     92,
#     93,
#     359,
#     503,
#     522,
#     542,
#     873,
#     893,
#     902,
#     918,
#     922,
#     931,
#     1350,
#     1853,
#     1982,
#     2460,
#     2627,
#     3246,
#     3253,
#     3268,
#     3536,
#     3846,
#     3961,
#     4183,
#     4667,
#     6585,
#     6647,
#     7273,
#     9061,
#     9383,
#     10428,
#     10929,
#     11938,
#     12033,
#     12331,
#     12562,
#     13793,
#     14157,
#     14635,
#     15265,
#     15618,
#     16553,
#     16604,
#     18362,
#     18956,
#     20075,
#     21675,
#     22520,
#     26130,
#     26161,
#     26435,
#     28279,
#     29464,
#     31650,
#     32302,
#     32470,
#     36865,
#     42863,
#     47425,
#     49870,
#     50254,
#     50258,
#     50360,
#     50361,
#     50362
#   ],
#   "torch_dtype": "float32",
#   "transformers_version": "4.40.0",
#   "use_cache": true,
#   "use_weighted_layer_sum": false,
#   "vocab_size": 51865
# }
#
# loading weights file model.safetensors from cache at /root/.cache/huggingface/hub/models--distil-whisper--distil-large-v2/snapshots/66bb165856c86b9eae9dba7830c0cd7d859f4ef4/model.safetensors
# Generate config GenerationConfig {
#   "begin_suppress_tokens": [
#     220,
#     50257
#   ],
#   "bos_token_id": 50257,
#   "decoder_start_token_id": 50258,
#   "eos_token_id": 50257,
#   "forced_decoder_ids": [
#     [
#       1,
#       50259
#     ],
#     [
#       2,
#       50359
#     ],
#     [
#       3,
#       50363
#     ]
#   ],
#   "max_length": 448,
#   "pad_token_id": 50257,
#   "suppress_tokens": [
#     1,
#     2,
#     7,
#     8,
#     9,
#     10,
#     14,
#     25,
#     26,
#     27,
#     28,
#     29,
#     31,
#     58,
#     59,
#     60,
#     61,
#     62,
#     63,
#     90,
#     91,
#     92,
#     93,
#     359,
#     503,
#     522,
#     542,
#     873,
#     893,
#     902,
#     918,
#     922,
#     931,
#     1350,
#     1853,
#     1982,
#     2460,
#     2627,
#     3246,
#     3253,
#     3268,
#     3536,
#     3846,
#     3961,
#     4183,
#     4667,
#     6585,
#     6647,
#     7273,
#     9061,
#     9383,
#     10428,
#     10929,
#     11938,
#     12033,
#     12331,
#     12562,
#     13793,
#     14157,
#     14635,
#     15265,
#     15618,
#     16553,
#     16604,
#     18362,
#     18956,
#     20075,
#     21675,
#     22520,
#     26130,
#     26161,
#     26435,
#     28279,
#     29464,
#     31650,
#     32302,
#     32470,
#     36865,
#     42863,
#     47425,
#     49870,
#     50254,
#     50258,
#     50360,
#     50361,
#     50362
#   ]
# }
#
# All model checkpoint weights were used when initializing WhisperForConditionalGeneration.
#
# All the weights of WhisperForConditionalGeneration were initialized from the model checkpoint at distil-whisper/distil-large-v2.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use WhisperForConditionalGeneration for predictions without further training.
# loading configuration file generation_config.json from cache at /root/.cache/huggingface/hub/models--distil-whisper--distil-large-v2/snapshots/66bb165856c86b9eae9dba7830c0cd7d859f4ef4/generation_config.json
# Generate config GenerationConfig {
#   "begin_suppress_tokens": [
#     220,
#     50257
#   ],
#   "bos_token_id": 50257,
#   "decoder_start_token_id": 50258,
#   "eos_token_id": 50257,
#   "forced_decoder_ids": [
#     [
#       1,
#       50259
#     ],
#     [
#       2,
#       50359
#     ],
#     [
#       3,
#       50363
#     ]
#   ],
#   "is_multilingual": true,
#   "lang_to_id": {
#     "<|af|>": 50327,
#     "<|am|>": 50334,
#     "<|ar|>": 50272,
#     "<|as|>": 50350,
#     "<|az|>": 50304,
#     "<|ba|>": 50355,
#     "<|be|>": 50330,
#     "<|bg|>": 50292,
#     "<|bn|>": 50302,
#     "<|bo|>": 50347,
#     "<|br|>": 50309,
#     "<|bs|>": 50315,
#     "<|ca|>": 50270,
#     "<|cs|>": 50283,
#     "<|cy|>": 50297,
#     "<|da|>": 50285,
#     "<|de|>": 50261,
#     "<|el|>": 50281,
#     "<|en|>": 50259,
#     "<|es|>": 50262,
#     "<|et|>": 50307,
#     "<|eu|>": 50310,
#     "<|fa|>": 50300,
#     "<|fi|>": 50277,
#     "<|fo|>": 50338,
#     "<|fr|>": 50265,
#     "<|gl|>": 50319,
#     "<|gu|>": 50333,
#     "<|haw|>": 50352,
#     "<|ha|>": 50354,
#     "<|he|>": 50279,
#     "<|hi|>": 50276,
#     "<|hr|>": 50291,
#     "<|ht|>": 50339,
#     "<|hu|>": 50286,
#     "<|hy|>": 50312,
#     "<|id|>": 50275,
#     "<|is|>": 50311,
#     "<|it|>": 50274,
#     "<|ja|>": 50266,
#     "<|jw|>": 50356,
#     "<|ka|>": 50329,
#     "<|kk|>": 50316,
#     "<|km|>": 50323,
#     "<|kn|>": 50306,
#     "<|ko|>": 50264,
#     "<|la|>": 50294,
#     "<|lb|>": 50345,
#     "<|ln|>": 50353,
#     "<|lo|>": 50336,
#     "<|lt|>": 50293,
#     "<|lv|>": 50301,
#     "<|mg|>": 50349,
#     "<|mi|>": 50295,
#     "<|mk|>": 50308,
#     "<|ml|>": 50296,
#     "<|mn|>": 50314,
#     "<|mr|>": 50320,
#     "<|ms|>": 50282,
#     "<|mt|>": 50343,
#     "<|my|>": 50346,
#     "<|ne|>": 50313,
#     "<|nl|>": 50271,
#     "<|nn|>": 50342,
#     "<|no|>": 50288,
#     "<|oc|>": 50328,
#     "<|pa|>": 50321,
#     "<|pl|>": 50269,
#     "<|ps|>": 50340,
#     "<|pt|>": 50267,
#     "<|ro|>": 50284,
#     "<|ru|>": 50263,
#     "<|sa|>": 50344,
#     "<|sd|>": 50332,
#     "<|si|>": 50322,
#     "<|sk|>": 50298,
#     "<|sl|>": 50305,
#     "<|sn|>": 50324,
#     "<|so|>": 50326,
#     "<|sq|>": 50317,
#     "<|sr|>": 50303,
#     "<|su|>": 50357,
#     "<|sv|>": 50273,
#     "<|sw|>": 50318,
#     "<|ta|>": 50287,
#     "<|te|>": 50299,
#     "<|tg|>": 50331,
#     "<|th|>": 50289,
#     "<|tk|>": 50341,
#     "<|tl|>": 50348,
#     "<|tr|>": 50268,
#     "<|tt|>": 50351,
#     "<|uk|>": 50280,
#     "<|ur|>": 50290,
#     "<|uz|>": 50337,
#     "<|vi|>": 50278,
#     "<|yi|>": 50335,
#     "<|yo|>": 50325,
#     "<|zh|>": 50260
#   },
#   "language": "<|en|>",
#   "max_initial_timestamp_index": 50,
#   "max_length": 448,
#   "no_timestamps_token_id": 50363,
#   "pad_token_id": 50257,
#   "prev_sot_token_id": 50361,
#   "return_timestamps": false,
#   "suppress_tokens": [
#     1,
#     2,
#     7,
#     8,
#     9,
#     10,
#     14,
#     25,
#     26,
#     27,
#     28,
#     29,
#     31,
#     58,
#     59,
#     60,
#     61,
#     62,
#     63,
#     90,
#     91,
#     92,
#     93,
#     359,
#     503,
#     522,
#     542,
#     873,
#     893,
#     902,
#     918,
#     922,
#     931,
#     1350,
#     1853,
#     1982,
#     2460,
#     2627,
#     3246,
#     3253,
#     3268,
#     3536,
#     3846,
#     3961,
#     4183,
#     4667,
#     6585,
#     6647,
#     7273,
#     9061,
#     9383,
#     10428,
#     10929,
#     11938,
#     12033,
#     12331,
#     12562,
#     13793,
#     14157,
#     14635,
#     15265,
#     15618,
#     16553,
#     16604,
#     18362,
#     18956,
#     20075,
#     21675,
#     22520,
#     26130,
#     26161,
#     26435,
#     28279,
#     29464,
#     31650,
#     32302,
#     32470,
#     36865,
#     42863,
#     47425,
#     49870,
#     50254,
#     50258,
#     50360,
#     50361,
#     50362
#   ],
#   "task": "transcribe",
#   "task_to_id": {
#     "transcribe": 50359,
#     "translate": 50358
#   },
#   "use_scan": false
# }
#
# loading file vocab.json from cache at /root/.cache/huggingface/hub/models--distil-whisper--distil-large-v2/snapshots/66bb165856c86b9eae9dba7830c0cd7d859f4ef4/vocab.json
# loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--distil-whisper--distil-large-v2/snapshots/66bb165856c86b9eae9dba7830c0cd7d859f4ef4/tokenizer.json
# loading file merges.txt from cache at /root/.cache/huggingface/hub/models--distil-whisper--distil-large-v2/snapshots/66bb165856c86b9eae9dba7830c0cd7d859f4ef4/merges.txt
# loading file normalizer.json from cache at /root/.cache/huggingface/hub/models--distil-whisper--distil-large-v2/snapshots/66bb165856c86b9eae9dba7830c0cd7d859f4ef4/normalizer.json
# loading file added_tokens.json from cache at /root/.cache/huggingface/hub/models--distil-whisper--distil-large-v2/snapshots/66bb165856c86b9eae9dba7830c0cd7d859f4ef4/added_tokens.json
# loading file special_tokens_map.json from cache at /root/.cache/huggingface/hub/models--distil-whisper--distil-large-v2/snapshots/66bb165856c86b9eae9dba7830c0cd7d859f4ef4/special_tokens_map.json
# loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--distil-whisper--distil-large-v2/snapshots/66bb165856c86b9eae9dba7830c0cd7d859f4ef4/tokenizer_config.json
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# loading configuration file preprocessor_config.json from cache at /root/.cache/huggingface/hub/models--distil-whisper--distil-large-v2/snapshots/66bb165856c86b9eae9dba7830c0cd7d859f4ef4/preprocessor_config.json
# Feature extractor WhisperFeatureExtractor {
#   "chunk_length": 30,
#   "feature_extractor_type": "WhisperFeatureExtractor",
#   "feature_size": 80,
#   "hop_length": 160,
#   "n_fft": 400,
#   "n_samples": 480000,
#   "nb_max_frames": 3000,
#   "padding_side": "right",
#   "padding_value": 0.0,
#   "processor_class": "WhisperProcessor",
#   "return_attention_mask": false,
#   "sampling_rate": 16000
# }
#
# You have passed task=transcribe, but also have set `forced_decoder_ids` to [[1, 50259], [2, 50359], [3, 50363]] which creates a conflict. `forced_decoder_ids` will be ignored in favor of task=transcribe.
# Eval results for step (198 / 198 | Eval Loss: 4.306909084320068 | Eval clap: 0.47522494196891785 | Eval wer: 19.84732824427481 |)
# wandb:
# wandb:
# wandb: Run history:
# wandb:           eval/clap ▁█
# wandb:          eval/epoch ▁█
# wandb:           eval/loss █▁
# wandb:           eval/time ▁█
# wandb:            eval/wer █▁
# wandb:         train/epoch ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁████████████████████
# wandb: train/learning_rate ▁▂▂▃▄▅▅▆▇▇██████████████████████████████
# wandb:          train/loss ██▅▅▄▄▄▄▃▃▃▃▃▂▂▂▂▂▃▂▃▃▂▂▃▃▂▁▂▂▂▃▃▂▂▃▂▃▃▃
# wandb:          train/time ▁▁▁▁▁▂▂▂▂▂▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇██
# wandb:
# wandb: Run summary:
# wandb:           eval/clap 0.47522
# wandb:          eval/epoch 1
# wandb:           eval/loss 4.30691
# wandb:           eval/time 38.48284
# wandb:            eval/wer 19.84733
# wandb:         train/epoch 1
# wandb: train/learning_rate 8e-05
# wandb:          train/loss 4.47595
# wandb:          train/time 3580.87747
# wandb:
# wandb: You can sync this run to the cloud by running:
# wandb: wandb sync /content/parler-tts/wandb/offline-run-20240430_145416-x4ghqjio
# wandb: Find logs at: ./wandb/offline-run-20240430_145416-x4ghqjio/logs
# /usr/local/lib/python3.10/dist-packages/wandb/sdk/wandb_run.py:2265: UserWarning: Run (x4ghqjio) is finished. The call to `_console_raw_callback` will be ignored. Please make sure that you are using an active run.
#   lambda data: self._console_raw_callback("stderr", data),
# Train steps ... : 100% 198/198 [1:03:19<00:00, 19.19s/it]

# %% [markdown]
# ## Inference
#
# The full training on the free T4 from Google Colab took about an hour.
# Now, let's see how to do inference with the newly fine-tuned model!

# %% [markdown]
# First install the Parler-TTS library:

# %%
# !pip install git+https://github.com/huggingface/parler-tts.git
# Out:
# Collecting git+https://github.com/huggingface/parler-tts.git
#   Cloning https://github.com/huggingface/parler-tts.git to /tmp/pip-req-build-arq29sva
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/parler-tts.git /tmp/pip-req-build-arq29sva
#   Resolved https://github.com/huggingface/parler-tts.git to commit 10016fb0300c0dc31a0fb70e26f3affee7b62f16
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: transformers>=4.34.0 in /usr/local/lib/python3.10/dist-packages (from parler_tts==0.1) (4.40.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from parler_tts==0.1) (2.2.1+cu121)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from parler_tts==0.1) (0.1.99)
# Requirement already satisfied: descript-audio-codec in /usr/local/lib/python3.10/dist-packages (from parler_tts==0.1) (1.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers>=4.34.0->parler_tts==0.1) (3.13.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.34.0->parler_tts==0.1) (0.22.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.34.0->parler_tts==0.1) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.34.0->parler_tts==0.1) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.34.0->parler_tts==0.1) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.34.0->parler_tts==0.1) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers>=4.34.0->parler_tts==0.1) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.34.0->parler_tts==0.1) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.34.0->parler_tts==0.1) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.34.0->parler_tts==0.1) (4.66.2)
# Requirement already satisfied: argbind>=0.3.7 in /usr/local/lib/python3.10/dist-packages (from descript-audio-codec->parler_tts==0.1) (0.3.7)
# Requirement already satisfied: descript-audiotools>=0.7.2 in /usr/local/lib/python3.10/dist-packages (from descript-audio-codec->parler_tts==0.1) (0.7.2)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (from descript-audio-codec->parler_tts==0.1) (0.8.0)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (from descript-audio-codec->parler_tts==0.1) (2.2.1+cu121)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->parler_tts==0.1) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->parler_tts==0.1) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->parler_tts==0.1) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->parler_tts==0.1) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->parler_tts==0.1) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->parler_tts==0.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->parler_tts==0.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->parler_tts==0.1) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch->parler_tts==0.1) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->parler_tts==0.1) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch->parler_tts==0.1) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch->parler_tts==0.1) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch->parler_tts==0.1) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch->parler_tts==0.1) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch->parler_tts==0.1) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch->parler_tts==0.1) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch->parler_tts==0.1) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->parler_tts==0.1) (12.4.127)
# Requirement already satisfied: docstring-parser in /usr/local/lib/python3.10/dist-packages (from argbind>=0.3.7->descript-audio-codec->parler_tts==0.1) (0.16)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.10/dist-packages (from descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (0.12.1)
# Requirement already satisfied: pyloudnorm in /usr/local/lib/python3.10/dist-packages (from descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (0.1.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (6.4.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (1.11.4)
# Requirement already satisfied: julius in /usr/local/lib/python3.10/dist-packages (from descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (0.2.7)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.10/dist-packages (from descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (0.3.2)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (7.34.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (13.7.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (3.7.1)
# Requirement already satisfied: librosa in /usr/local/lib/python3.10/dist-packages (from descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (0.10.1)
# Requirement already satisfied: pystoi in /usr/local/lib/python3.10/dist-packages (from descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (0.4.1)
# Requirement already satisfied: torch-stoi in /usr/local/lib/python3.10/dist-packages (from descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (0.2.1)
# Requirement already satisfied: flatten-dict in /usr/local/lib/python3.10/dist-packages (from descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (0.4.2)
# Requirement already satisfied: markdown2 in /usr/local/lib/python3.10/dist-packages (from descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (2.4.13)
# Requirement already satisfied: randomname in /usr/local/lib/python3.10/dist-packages (from descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (0.2.1)
# Collecting protobuf<3.20,>=3.9.2 (from descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1)
#   Using cached protobuf-3.19.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (2.15.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->parler_tts==0.1) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.34.0->parler_tts==0.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.34.0->parler_tts==0.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.34.0->parler_tts==0.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.34.0->parler_tts==0.1) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->parler_tts==0.1) (1.3.0)
# Requirement already satisfied: six<2.0,>=1.12 in /usr/local/lib/python3.10/dist-packages (from flatten-dict->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (1.16.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (3.0.43)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (4.9.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (3.0.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from librosa->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (1.4.0)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (0.58.1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (1.8.1)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (0.3.7)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (1.0.8)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (2.8.2)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.10/dist-packages (from pyloudnorm->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (0.18.3)
# Requirement already satisfied: fire in /usr/local/lib/python3.10/dist-packages (from randomname->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (0.6.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (3.0.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (1.62.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (3.0.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (2.22)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (0.1.2)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (0.41.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (0.7.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.0->librosa->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (4.2.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (0.2.13)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->librosa->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (3.4.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire->randomname->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (2.4.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard->descript-audiotools>=0.7.2->descript-audio-codec->parler_tts==0.1) (3.2.2)
# Building wheels for collected packages: parler_tts
#   Building wheel for parler_tts (pyproject.toml) ... done
#   Created wheel for parler_tts: filename=parler_tts-0.1-py3-none-any.whl size=40796 sha256=08cffceafde39484b5a5a844c872a44e24d02daf31a7ed27691eca681c6d37de
#   Stored in directory: /tmp/pip-ephem-wheel-cache-41otsqqv/wheels/08/9a/16/7c5e21266463d789fae86d97edb74efc55318f7946736cc645
# Successfully built parler_tts
# Installing collected packages: protobuf, parler_tts
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.3
#     Uninstalling protobuf-4.25.3:
#       Successfully uninstalled protobuf-4.25.3
#   Attempting uninstall: parler_tts
#     Found existing installation: parler_tts 0.1
#     Uninstalling parler_tts-0.1:
#       Successfully uninstalled parler_tts-0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorboardx 2.6.2.2 requires protobuf>=3.20, but you have protobuf 3.19.6 which is incompatible.
# tensorflow 2.15.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 3.19.6 which is incompatible.
# tensorflow-datasets 4.9.4 requires protobuf>=3.20, but you have protobuf 3.19.6 which is incompatible.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 3.19.6 which is incompatible.
# Successfully installed parler_tts-0.1 protobuf-3.19.6

# %% [markdown]
# Then:

# %%
from parler_tts import ParlerTTSForConditionalGeneration
from transformers import AutoTokenizer
import torch

device = "cuda:0" if torch.cuda.is_available() else "cpu"

model = ParlerTTSForConditionalGeneration.from_pretrained("/content/parler-tts/output_dir_training", torch_dtype=torch.float16).to(device)
tokenizer = AutoTokenizer.from_pretrained("parler-tts/parler_tts_mini_v0.1")

prompt = "Hey, how are you doing today?"
description = "'Jenny delivers her words quite expressively, in a very confined sounding environment with clear audio quality. She speaks fast.'"

input_ids = tokenizer(description, return_tensors="pt").input_ids.to(device)
prompt_input_ids = tokenizer(prompt, return_tensors="pt").input_ids.to(device)

generation = model.generate(input_ids=input_ids, prompt_input_ids=prompt_input_ids)
audio_arr = generation.cpu().numpy().squeeze()
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/utils/weight_norm.py:28: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# WARNING:parler_tts.modeling_parler_tts:Using the model-agnostic default `max_length` (=2580) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.

# %%
from IPython.display import Audio
Audio(audio_arr, rate=model.config.sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
prompt = "Wow, I've really got the same voice as Jenny, huh?"

prompt_input_ids = tokenizer(prompt, return_tensors="pt").input_ids.to(device)

generation = model.generate(input_ids=input_ids, prompt_input_ids=prompt_input_ids)
audio_arr = generation.cpu().numpy().squeeze()

Audio(audio_arr, rate=model.config.sampling_rate)
# Out:
# WARNING:parler_tts.modeling_parler_tts:Using the model-agnostic default `max_length` (=2580) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
prompt = "What a time to be alive!"
description = "'Jenny's speech is very clear, and she speaks in a very monotone voice, really slowly and with minimal variation in speed.'"

input_ids = tokenizer(description, return_tensors="pt").input_ids.to(device)
prompt_input_ids = tokenizer(prompt, return_tensors="pt").input_ids.to(device)

generation = model.generate(input_ids=input_ids, prompt_input_ids=prompt_input_ids)
audio_arr = generation.cpu().numpy().squeeze()

Audio(audio_arr, rate=model.config.sampling_rate)
# Out:
# WARNING:parler_tts.modeling_parler_tts:Using the model-agnostic default `max_length` (=2580) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# This is great! As you can see, the model now managed to get a **consistent** voice throughout generation that looks like **Jenny**!
#
# Since we're quite happy about it, let's push it to the hub to be able to re-use it!

# %%
model.push_to_hub("parler-tts-mini-Jenny-colab")
tokenizer.push_to_hub("parler-tts-mini-Jenny-colab")
# Out:
# model.safetensors:   0%|          | 0.00/1.29G [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/5.17k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/ylacombe/parler-tts-mini-Jenny-colab/commit/4f73db54a28230d3b95fb9b4507408ab71692b01', commit_message='Upload tokenizer', commit_description='', oid='4f73db54a28230d3b95fb9b4507408ab71692b01', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# You'll now be able to load the model and the tokenizer using the direct repository id of your model, i.e `<your_HF_handle>/parler-tts-mini-Jenny-colab`.
#
# ```python
# model = ParlerTTSForConditionalGeneration.from_pretrained("<your_HF_handle>/parler-tts-mini-Jenny-colab").to(device)
# tokenizer = AutoTokenizer.from_pretrained("<your_HF_handle>/parler-tts-mini-Jenny-colab")
# ```

# %% [markdown]
# ## Conclusion
#
# To conclude, we've shown here:
# 1. how to annotate a single-speaker 6-hours-long dataset
# 2. how to fine-tune Parler-TTS Mini v0.1 on this newly created dataset!
#
# **If you want to fine-tune the model on your own dataset, you can follow and/or adapt the current notebook to make it work! Don't forget to check how to push your own local dataset on the HuggingFace Hub using a [script similar to what's described in the Data-Speech FAQ](https://github.com/huggingface/dataspeech?tab=readme-ov-file#how-do-i-use-datasets-that-i-have-with-this-repository)!**
